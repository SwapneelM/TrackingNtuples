# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import uproot
import pandas as pd

# %%
gen_event_ = "ttbar-100"
outfile_ = "outfile-" + gen_event_ + ".root"
data_ = uproot.open(outfile_)["ntuples"]["tree"]
data_.keys()
# Out:
# ['nevent',
#  'nlumi',
#  'nrun',
#  'trackEta',
#  'trackPhi',
#  'qoverp',
#  'dxy',
#  'dsz',
#  'trackPt',
#  'trackTPIdx',
#  'trackEtaError',
#  'trackPhiError',
#  'qoverpError',
#  'dxyError',
#  'dszError',
#  'trackPtError',
#  'trackParameters',
#  'covarianceArray',
#  'stereoHitX',
#  'stereoHitY',
#  'stereoHitZ',
#  'stereoHitR',
#  'stereoHitPhi',
#  'stereoHitEta',
#  'stereoHitLayer',
#  'stereoTPIndex',
#  'stereoHitMatch',
#  'monoHitX',
#  'monoHitY',
#  'monoHitZ',
#  'monoHitR',
#  'monoHitPhi',
#  'monoHitEta',
#  'monoHitLayer',
#  'monoTPIndex',
#  'monoHitMatch']

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig_ = plt.figure()
ax_ = Axes3D(fig_)

# %%
# Find Number of Events based on any property length
track_eta_ = data_.array("trackEta")
print "Number of Events: ", len(track_eta_)
# Out:
# Number of Events:  100

# %%
# Iterate over 5 track parameters and plot their distribution
for i, key in zip(range(5), ["trackEta", "trackPhi", "qoverp", "dxy", "dsz"]):
    track_param_ = data_.array(key)
    concat_track_param_ = []
    
    for j in range(len(track_param_)):
        concat_track_param_.extend(track_param_[j])
    print "Iterating over", key, "from", len(concat_track_param_), "tracks"
    
    plt.clf()
    ax_ = plt.subplot()
    ax_.hist(concat_track_param_, histtype='stepfilled', bins=40, orientation='vertical')
    plt.grid(True)
    plt.ylabel('Frequency')
    plt.xlabel('Distribution of ' + key)
    plt.title(key + ' Distribution')
    plt.savefig('plots/' + gen_event_ + '/track/' + key)
    plt.show()
# Out:
# Iterating over trackEta from 4654 tracks
# Iterating over trackPhi from 4654 tracks
# Iterating over qoverp from 4654 tracks
# Iterating over dxy from 4654 tracks
# Iterating over dsz from 4654 tracks

# %%
# Check what is causing trackPhi aberrations

track_phi_ = data_.array('trackPhi')
concat_track_phi_ = []
anomalous_phi_event_number_ = []
for i in range(len(track_phi_)):
    
    for j in range(len(track_phi_[i])):
        if (track_phi_[i][j] >= -0.8) and (track_phi_[i][j] <= 2):
            anomalous_phi_event_number_.append(i)
            continue
        else:    
            concat_track_phi_.append(track_phi_[i][j])
        
print len(concat_track_phi_)
ax_ = plt.subplot()
ax_.hist(concat_track_phi_, histtype='stepfilled', bins=40, orientation='vertical')
plt.grid(True)
plt.ylabel('Frequency')
plt.xlabel('Distribution of Track Phi')
plt.title('Weird Track Phi Distribution')
plt.show()
# Out:
# 2919

# %%
# Plot histogram of events with oddly low track phi
check_events_with_odd_phi_ = np.bincount(anomalous_phi_event_number_)
index_of_weird_events_ = list(set(anomalous_phi_event_number_))
# print anomalous_phi_event_number_
ax_ = plt.subplot()
ax_.hist(index_of_weird_events_, weights=check_events_with_odd_phi_, bins=100, orientation='vertical')
plt.grid(True)
plt.ylabel('Frequency of Low Phi')
plt.xlabel('Event Numbers')
plt.title('Low Track Phi Distribution across Events')
plt.show()

# %%
plt.clf()

# %%
# Plot the distribution of tracks in events 
# using the length of any paramater array - e.g. track eta

track_Eta_ = data_.array("trackEta")
concat_num_tracks_ = []

for i in range(len(track_Eta_)):
     concat_num_tracks_.append(len(track_Eta_[i]))
print "Added", sum(concat_num_tracks_), "tracks from", len(concat_num_tracks_), "events"
ax_ = plt.subplot()
ax_.hist(concat_num_tracks_, histtype='bar', bins=80, align='mid', orientation='vertical')

plt.xlabel('No. of Tracks')
plt.ylabel('No. of Events')
plt.title('Tracks vs. Events Distribution')
plt.grid(True)
plt.savefig('plots/' + gen_event_ + '/track/event-track-distribution')
plt.show()
# Out:
# Added 4654 tracks from 100 events

# %%
# ToDo: Add lognorm colormap

mono_x_ = data_.array("monoHitX") 
mono_y_ = data_.array("monoHitY")
mono_z_ = data_.array("monoHitZ")

 

if len(mono_x_) == len(mono_y_):
    concat_mono_x_ = []
    concat_mono_y_ = []

    for i in range(len(mono_x_)):
        concat_mono_x_.extend(mono_x_[i])
        concat_mono_y_.extend(mono_y_[i])

plt.clf()
fig, ax_ = plt.subplots(figsize=(8, 8))
# Plot the 2D Histogram for Mono Rechits
plt.title('MonoRechit Distribution')
ax_.patch.set_facecolor('black')
plt.hist2d(concat_mono_x_, concat_mono_y_, bins=300, norm=matplotlib.colors.LogNorm(), cmap='hot')
plt.savefig('plots/' + gen_event_ + '/stereo/rechitdistribution')
plt.show()

# %%
# ToDo: Add lognorm colormap

stereo_x_ = data_.array("stereoHitX") 
stereo_y_ = data_.array("stereoHitY")
stereo_z_ = data_.array("stereoHitZ")

 

if len(mono_x_) == len(mono_y_):
    concat_stereo_x_ = []
    concat_stereo_y_ = []

    for i in range(len(mono_x_)):
        concat_stereo_x_.extend(stereo_x_[i])
        concat_stereo_y_.extend(stereo_y_[i])

plt.clf()
fig, ax_ = plt.subplots(figsize=(8, 8))
# Plot the 2D Histogram for Mono Rechits
ax_.set_title('Stereo Distribution')
ax_.patch.set_facecolor('black')
ax_.hist2d(concat_stereo_x_, concat_stereo_y_, bins=300, norm=matplotlib.colors.LogNorm(), cmap='hot')
plt.savefig('plots/' + gen_event_ + '/stereo/rechitdistribution')
plt.show()

# %%
# Define a loop that plots R, Phi, and Eta for Mono Hits
position_ = 1
for param in ["monoHitR", "monoHitPhi", "monoHitEta"]:
    mono_param_ = data_.array(param)
    concat_mono_param_ = []
    
    for i in range(len(mono_param_)):
            concat_mono_param_.extend(mono_param_[i])

    plt.clf()
    fig, ax_ = plt.subplots(figsize=(8, 6))
    position_ += 1
    # Plot the 2D Histogram for Mono Rechits
    ax_.set_title('MonoRechit Distribution of ' + param)
    ax_.hist(concat_mono_param_, bins=50, histtype='stepfilled', align='mid', orientation='vertical', density=True)
    plt.xlabel('Value of ' + param)
    plt.ylabel('Distribution of ' + param)
    plt.title(param + ' Distribution')
    plt.grid(True)
    plt.savefig('plots/' + gen_event_ + '/mono/' + param)
    plt.show()

# %%
# Define a loop that plots R, Phi, and Eta for Stereo Hits

for param in ["stereoHitR", "stereoHitPhi", "stereoHitEta"]:
    stereo_param_ = data_.array(param)
    concat_stereo_param_ = []
    
    for i in range(len(mono_param_)):
            concat_stereo_param_.extend(stereo_param_[i])

    plt.clf()
    fig, ax_ = plt.subplots(figsize=(8, 6))
    position_ += 1
    # Plot the 2D Histogram for Mono Rechits
    ax_.set_title('StereoRechit Distribution of ' + param)
    ax_.hist(concat_stereo_param_, bins=50, histtype='stepfilled', align='mid', orientation='vertical', density=True)
    plt.xlabel('Value of ' + param)
    plt.ylabel('Distribution of ' + param)
    plt.title(param + ' Distribution')
    plt.grid(True)
    plt.savefig('plots/' + gen_event_ + '/stereo/' + param)
    plt.show()

# %%
stereo_tp_idx_ = data_.array('stereoTPIndex')
track_tp_idx_ = data_.array('trackTPIdx')
# Check that both have been generated for the same number of events
# Just for clarity
print len(track_tp_idx_) == len(stereo_tp_idx_), 
print " Both have", len(track_tp_idx_), "events"
# Out:
# True  Both have 100 events

# %%
# Check if any tracks map to multiple tracking particles
for i in range(len(track_tp_idx_)):
    for track_tp_list_ in track_tp_idx_[i]:
        if len(track_tp_list_) > 1:
            print "Track maps to multiple TPs in event", i

# %%
# Check if any hits map to multiple tracking particles
hit_tp_count_ = {}

for i in range(len(stereo_tp_idx_)):
    for stereo_tp_list_ in stereo_tp_idx_[i]:
        tmp_len_ = len(stereo_tp_list_)
        # Add to a dictionary of <num of TP matches : hit count>
        if tmp_len_ in hit_tp_count_:
            hit_tp_count_[tmp_len_] += 1
        else:
            hit_tp_count_[tmp_len_] = 1

# This prints how many hits map to multiple matches
# <num matches to TPs: ncount of hits>
print "Number of matches and number of hits with those many TP matches\n", hit_tp_count_
# Out:
# Number of matches and number of hits with those many TP matches
# {0: 46023, 1: 132680, 2: 1521, 3: 89, 4: 13, 5: 3, 6: 1, 7: 2, 9: 2}

# %%
# Check that the same number of entries are recorded for stereo rechits
concat_stereo_tp_idx_ = []
for i in range(len(stereo_tp_idx_)):
    concat_stereo_tp_idx_.extend(stereo_tp_idx_[i])
    
print len(concat_stereo_tp_idx_) == len(concat_stereo_param_)
# Out:
# True

# %%
import pandas as pd

# %%
'''
Define a dataframe as follows

:Event ID: int
:Track ID: int
:TP Index: list(int)
:Rechit IDs: list(int)
'''

# %%
detatemp_ = {"Event ID": [0,0,0,0], "Track ID":[0,0,0,0], "TP Index":[[1,2,3], [1,2,3], [1,0], [2,3]], "Rechit IDs":[[1,2,3], [1,2,3], [1,0], [2,3]]}

dataframe_ = pd.DataFrame(detatemp_, 
                    columns=["Event ID", "Track ID", "TP Index", "Rechit IDs"])

dataframe_
# Out:
#    Event ID  Track ID   TP Index Rechit IDs
# 0         0         0  [1, 2, 3]  [1, 2, 3]
# 1         0         0  [1, 2, 3]  [1, 2, 3]
# 2         0         0     [1, 0]     [1, 0]
# 3         0         0     [2, 3]     [2, 3]

# %%
# Unique index associated with every single track

# If you do this, you add all the tracks sequentially 
# but when you want to search, it is not per-event so you 
# will lose the segregation of tracks by event
concat_track_tp_idx_ = {}
idx_ = 0

for event_ in range(len(track_tp_idx_)):
    for tp_list_ in track_tp_idx_[event_]:
        concat_track_tp_idx_[(event_, idx_)] = tp_list_
        idx_ += 1

track_count_ = len(concat_track_tp_idx_)
print track_count_, "total tracks found"

# Check how many tracks have multiple TPs
for key, value in concat_track_tp_idx_.items():
    # Track matched to >1 TP
    if len(value) > 1:
        print "Track", key, "matched to TPs", value
# Out:
# 4654 total tracks found

# %%
# Unique index associated with every single stereo rechit

# If you do this, you add all the stereo rechits sequentially 
# but when you want to search, it is not per-event so you 
# will lose the segregation of rechits by event
concat_stereo_tp_idx_ = {}
idx_ = 0

for event_ in range(len(stereo_tp_idx_)):
    for tp_list_ in stereo_tp_idx_[event_]:
        concat_stereo_tp_idx_[(event_, idx_)] = tp_list_
        idx_ += 1

stereo_count_ = len(concat_stereo_tp_idx_)
print stereo_count_, "total stereohits found"

# Check how many stereo hits have multiple TPs
for key, value in concat_stereo_tp_idx_.items():
    # Track matched to >1 TP
    if len(value) > 1:
        # Dictionaries are unordered by default so this won't be sorted by event index
        print "<Event, Hit Index>", key, "matched to TPs", value
# Out:
# 180334 total stereohits found
# <Event, Hit Index> (29, 57788) matched to TPs [301, 300]
# <Event, Hit Index> (11, 23997) matched to TPs [697, 542]
# <Event, Hit Index> (28, 56429) matched to TPs [502, 501]
# <Event, Hit Index> (42, 78823) matched to TPs [1101, 1094, 145]
# <Event, Hit Index> (22, 43190) matched to TPs [917, 63]
# <Event, Hit Index> (88, 161938) matched to TPs [503, 110]
# <Event, Hit Index> (42, 78545) matched to TPs [779, 778]
# <Event, Hit Index> (15, 31727) matched to TPs [477, 475]
# <Event, Hit Index> (71, 132258) matched to TPs [147, 107]
# <Event, Hit Index> (75, 138058) matched to TPs [59, 34]
# <Event, Hit Index> (44, 81778) matched to TPs [127, 12]
# <Event, Hit Index> (52, 95261) matched to TPs [198, 194]
# <Event, Hit Index> (19, 38355) matched to TPs [571, 570]
# <Event, Hit Index> (81, 146730) matched to TPs [60, 46]
# <Event, Hit Index> (70, 130858) matched to TPs [52, 9]
# <Event, Hit Index> (0, 1513) matched to TPs [551, 407]
# <Event, Hit Index> (68, 127746) matched to TPs [208, 207]
# <Event, Hit Index> (73, 134776) matched to TPs [592, 176]
# <Event, Hit Index> (61, 114368) matched to TPs [616, 615, 609]
# <Event, Hit Index> (49, 89663) matched to TPs [173, 172]
# <Event, Hit Index> (10, 22241) matched to TPs [693, 545]
# <Event, Hit Index> (18, 36553) matched to TPs [158, 62]
# <Event, Hit Index> (93, 169746) matched to TPs [572, 571]
# <Event, Hit Index> (57, 106546) matched to TPs [824, 808]
# <Event, Hit Index> (82, 149406) matched to TPs [567, 558]
# <Event, Hit Index> (25, 50834) matched to TPs [680, 39]
# <Event, Hit Index> (19, 38178) matched to TPs [895, 890]
# <Event, Hit Index> (38, 70507) matched to TPs [324, 104]
# <Event, Hit Index> (45, 82397) matched to TPs [887, 13]
# <Event, Hit Index> (84, 154591) matched to TPs [1083, 1002]
# <Event, Hit Index> (76, 140422) matched to TPs [345, 121]
# <Event, Hit Index> (7, 17660) matched to TPs [722, 712]
# <Event, Hit Index> (77, 141390) matched to TPs [216, 34]
# <Event, Hit Index> (73, 135206) matched to TPs [405, 396, 395]
# <Event, Hit Index> (62, 115963) matched to TPs [512, 495]
# <Event, Hit Index> (40, 74527) matched to TPs [1113, 679]
# <Event, Hit Index> (28, 56498) matched to TPs [165, 154]
# <Event, Hit Index> (55, 100685) matched to TPs [170, 130]
# <Event, Hit Index> (38, 71038) matched to TPs [74, 5]
# <Event, Hit Index> (61, 114795) matched to TPs [371, 327]
# <Event, Hit Index> (57, 104872) matched to TPs [659, 195]
# <Event, Hit Index> (50, 91883) matched to TPs [727, 724]
# <Event, Hit Index> (38, 70431) matched to TPs [75, 74]
# <Event, Hit Index> (57, 104716) matched to TPs [291, 234]
# <Event, Hit Index> (30, 59546) matched to TPs [573, 171]
# <Event, Hit Index> (11, 24432) matched to TPs [800, 178, 109]
# <Event, Hit Index> (21, 43045) matched to TPs [936, 935]
# <Event, Hit Index> (19, 37592) matched to TPs [311, 36]
# <Event, Hit Index> (38, 70932) matched to TPs [248, 188]
# <Event, Hit Index> (10, 22540) matched to TPs [657, 656]
# <Event, Hit Index> (73, 135896) matched to TPs [951, 899]
# <Event, Hit Index> (21, 41114) matched to TPs [1029, 168]
# <Event, Hit Index> (3, 7179) matched to TPs [1343, 793]
# <Event, Hit Index> (80, 145693) matched to TPs [57, 13]
# <Event, Hit Index> (19, 38734) matched to TPs [929, 928, 927, 925, 924, 922]
# <Event, Hit Index> (23, 46401) matched to TPs [829, 608, 368]
# <Event, Hit Index> (79, 144515) matched to TPs [708, 693]
# <Event, Hit Index> (47, 85434) matched to TPs [425, 222, 178]
# <Event, Hit Index> (53, 96117) matched to TPs [426, 156]
# <Event, Hit Index> (7, 17680) matched to TPs [611, 610]
# <Event, Hit Index> (6, 15587) matched to TPs [111, 61]
# <Event, Hit Index> (50, 91234) matched to TPs [759, 48]
# <Event, Hit Index> (42, 78132) matched to TPs [687, 243]
# <Event, Hit Index> (6, 15265) matched to TPs [726, 96]
# <Event, Hit Index> (37, 69929) matched to TPs [127, 10]
# <Event, Hit Index> (24, 48694) matched to TPs [266, 221]
# <Event, Hit Index> (72, 133988) matched to TPs [372, 123]
# <Event, Hit Index> (44, 81903) matched to TPs [145, 120]
# <Event, Hit Index> (50, 91534) matched to TPs [874, 867]
# <Event, Hit Index> (40, 75394) matched to TPs [411, 410]
# <Event, Hit Index> (21, 41339) matched to TPs [1071, 2]
# <Event, Hit Index> (39, 72509) matched to TPs [270, 26]
# <Event, Hit Index> (57, 106005) matched to TPs [631, 58]
# <Event, Hit Index> (3, 6500) matched to TPs [123, 1]
# <Event, Hit Index> (90, 164433) matched to TPs [202, 201, 200, 199, 153]
# <Event, Hit Index> (10, 22161) matched to TPs [537, 182, 24]
# <Event, Hit Index> (39, 71950) matched to TPs [217, 216]
# <Event, Hit Index> (57, 104654) matched to TPs [154, 86]
# <Event, Hit Index> (97, 176116) matched to TPs [240, 238]
# <Event, Hit Index> (77, 140825) matched to TPs [172, 171]
# <Event, Hit Index> (57, 106933) matched to TPs [577, 551]
# <Event, Hit Index> (92, 168375) matched to TPs [416, 204]
# <Event, Hit Index> (21, 41505) matched to TPs [380, 141]
# <Event, Hit Index> (73, 136459) matched to TPs [186, 185]
# <Event, Hit Index> (14, 28461) matched to TPs [54, 53]
# <Event, Hit Index> (94, 171130) matched to TPs [561, 184]
# <Event, Hit Index> (73, 136296) matched to TPs [575, 358]
# <Event, Hit Index> (11, 23778) matched to TPs [630, 629]
# <Event, Hit Index> (1, 3239) matched to TPs [561, 5]
# <Event, Hit Index> (25, 50327) matched to TPs [301, 300]
# <Event, Hit Index> (65, 121720) matched to TPs [480, 479]
# <Event, Hit Index> (0, 1324) matched to TPs [554, 215]
# <Event, Hit Index> (57, 105648) matched to TPs [1243, 4]
# <Event, Hit Index> (7, 17659) matched to TPs [182, 171]
# <Event, Hit Index> (0, 510) matched to TPs [400, 0]
# <Event, Hit Index> (40, 74744) matched to TPs [849, 788]
# <Event, Hit Index> (38, 71549) matched to TPs [276, 176]
# <Event, Hit Index> (29, 57811) matched to TPs [638, 637, 636]
# <Event, Hit Index> (22, 45228) matched to TPs [926, 782]
# <Event, Hit Index> (39, 73558) matched to TPs [635, 191]
# <Event, Hit Index> (37, 69811) matched to TPs [441, 368]
# <Event, Hit Index> (21, 41853) matched to TPs [508, 113]
# <Event, Hit Index> (16, 32656) matched to TPs [235, 221, 220]
# <Event, Hit Index> (67, 126831) matched to TPs [177, 176]
# <Event, Hit Index> (54, 98901) matched to TPs [916, 354]
# <Event, Hit Index> (65, 123151) matched to TPs [171, 103]
# <Event, Hit Index> (66, 125708) matched to TPs [437, 184]
# <Event, Hit Index> (85, 155418) matched to TPs [130, 129]
# <Event, Hit Index> (3, 9425) matched to TPs [1223, 1217, 730]
# <Event, Hit Index> (18, 36556) matched to TPs [493, 492]
# <Event, Hit Index> (0, 905) matched to TPs [735, 493]
# <Event, Hit Index> (54, 98460) matched to TPs [1027, 143]
# <Event, Hit Index> (8, 18298) matched to TPs [758, 757]
# <Event, Hit Index> (61, 114728) matched to TPs [536, 433]
# <Event, Hit Index> (3, 7502) matched to TPs [1352, 1348]
# <Event, Hit Index> (50, 90582) matched to TPs [266, 265, 74]
# <Event, Hit Index> (60, 112090) matched to TPs [599, 598]
# <Event, Hit Index> (11, 23529) matched to TPs [681, 606]
# <Event, Hit Index> (87, 160826) matched to TPs [463, 462]
# <Event, Hit Index> (81, 147821) matched to TPs [227, 226]
# <Event, Hit Index> (21, 43107) matched to TPs [1065, 1061]
# <Event, Hit Index> (73, 135782) matched to TPs [611, 610]
# <Event, Hit Index> (21, 42142) matched to TPs [240, 88]
# <Event, Hit Index> (87, 160703) matched to TPs [81, 21]
# <Event, Hit Index> (71, 132376) matched to TPs [546, 544]
# <Event, Hit Index> (24, 48412) matched to TPs [263, 252, 251]
# <Event, Hit Index> (8, 18765) matched to TPs [725, 112]
# <Event, Hit Index> (3, 9422) matched to TPs [1221, 1218]
# <Event, Hit Index> (58, 108848) matched to TPs [952, 819]
# <Event, Hit Index> (16, 33478) matched to TPs [659, 658]
# <Event, Hit Index> (42, 77548) matched to TPs [299, 140]
# <Event, Hit Index> (81, 148548) matched to TPs [773, 429]
# <Event, Hit Index> (16, 34234) matched to TPs [117, 8]
# <Event, Hit Index> (66, 125179) matched to TPs [442, 441]
# <Event, Hit Index> (31, 61920) matched to TPs [694, 693]
# <Event, Hit Index> (84, 153146) matched to TPs [552, 551]
# <Event, Hit Index> (49, 89195) matched to TPs [512, 470]
# <Event, Hit Index> (58, 108781) matched to TPs [1007, 1005]
# <Event, Hit Index> (7, 16919) matched to TPs [278, 277]
# <Event, Hit Index> (34, 65175) matched to TPs [364, 363]
# <Event, Hit Index> (82, 149608) matched to TPs [95, 43]
# <Event, Hit Index> (22, 45004) matched to TPs [515, 514]
# <Event, Hit Index> (2, 5131) matched to TPs [365, 220]
# <Event, Hit Index> (10, 22454) matched to TPs [652, 645]
# <Event, Hit Index> (38, 70792) matched to TPs [607, 605]
# <Event, Hit Index> (48, 88048) matched to TPs [690, 97]
# <Event, Hit Index> (77, 141927) matched to TPs [315, 33]
# <Event, Hit Index> (99, 180094) matched to TPs [315, 101, 23]
# <Event, Hit Index> (43, 80395) matched to TPs [82, 62]
# <Event, Hit Index> (7, 16815) matched to TPs [229, 28]
# <Event, Hit Index> (88, 162595) matched to TPs [169, 37]
# <Event, Hit Index> (50, 92426) matched to TPs [1013, 1012]
# <Event, Hit Index> (44, 80893) matched to TPs [173, 38]
# <Event, Hit Index> (5, 11749) matched to TPs [977, 3]
# <Event, Hit Index> (53, 95983) matched to TPs [200, 193]
# <Event, Hit Index> (35, 66605) matched to TPs [508, 506]
# <Event, Hit Index> (26, 53383) matched to TPs [143, 99]
# <Event, Hit Index> (7, 17879) matched to TPs [278, 129]
# <Event, Hit Index> (8, 19230) matched to TPs [231, 113]
# <Event, Hit Index> (82, 149813) matched to TPs [346, 101]
# <Event, Hit Index> (6, 16003) matched to TPs [413, 412]
# <Event, Hit Index> (11, 23565) matched to TPs [681, 17]
# <Event, Hit Index> (28, 56644) matched to TPs [149, 58]
# <Event, Hit Index> (53, 95918) matched to TPs [685, 207]
# <Event, Hit Index> (73, 134306) matched to TPs [873, 872]
# <Event, Hit Index> (45, 82197) matched to TPs [217, 216]
# <Event, Hit Index> (34, 65673) matched to TPs [560, 301]
# <Event, Hit Index> (39, 73011) matched to TPs [527, 321]
# <Event, Hit Index> (30, 58755) matched to TPs [221, 219]
# <Event, Hit Index> (85, 155557) matched to TPs [211, 71]
# <Event, Hit Index> (78, 142529) matched to TPs [228, 227]
# <Event, Hit Index> (52, 95629) matched to TPs [725, 89]
# <Event, Hit Index> (88, 161696) matched to TPs [304, 29]
# <Event, Hit Index> (71, 131621) matched to TPs [47, 7]
# <Event, Hit Index> (24, 48227) matched to TPs [429, 53]
# <Event, Hit Index> (50, 91535) matched to TPs [879, 875, 872, 871, 870, 869, 868, 867, 866]
# <Event, Hit Index> (58, 108251) matched to TPs [784, 783]
# <Event, Hit Index> (60, 112348) matched to TPs [302, 202]
# <Event, Hit Index> (19, 38403) matched to TPs [220, 219]
# <Event, Hit Index> (24, 49341) matched to TPs [154, 152]
# <Event, Hit Index> (39, 72508) matched to TPs [270, 26]
# <Event, Hit Index> (81, 147563) matched to TPs [265, 240]
# <Event, Hit Index> (50, 90352) matched to TPs [981, 980]
# <Event, Hit Index> (59, 110956) matched to TPs [476, 168]
# <Event, Hit Index> (26, 53497) matched to TPs [680, 672]
# <Event, Hit Index> (58, 108151) matched to TPs [970, 967]
# <Event, Hit Index> (57, 106932) matched to TPs [577, 551]
# <Event, Hit Index> (88, 161556) matched to TPs [304, 303]
# <Event, Hit Index> (26, 52362) matched to TPs [28, 27]
# <Event, Hit Index> (52, 94468) matched to TPs [552, 550]
# <Event, Hit Index> (60, 111900) matched to TPs [196, 47]
# <Event, Hit Index> (2, 5176) matched to TPs [198, 113]
# <Event, Hit Index> (6, 14559) matched to TPs [792, 791, 54]
# <Event, Hit Index> (59, 110598) matched to TPs [753, 298]
# <Event, Hit Index> (27, 54970) matched to TPs [651, 34]
# <Event, Hit Index> (0, 230) matched to TPs [494, 493]
# <Event, Hit Index> (96, 173973) matched to TPs [445, 95]
# <Event, Hit Index> (22, 43806) matched to TPs [897, 896]
# <Event, Hit Index> (88, 161834) matched to TPs [189, 188]
# <Event, Hit Index> (57, 105101) matched to TPs [783, 2]
# <Event, Hit Index> (57, 104517) matched to TPs [303, 300]
# <Event, Hit Index> (13, 27081) matched to TPs [462, 461, 460, 33]
# <Event, Hit Index> (14, 28429) matched to TPs [605, 604]
# <Event, Hit Index> (68, 127665) matched to TPs [88, 72]
# <Event, Hit Index> (79, 144281) matched to TPs [1003, 37]
# <Event, Hit Index> (36, 68007) matched to TPs [264, 121]
# <Event, Hit Index> (7, 17455) matched to TPs [606, 94]
# <Event, Hit Index> (77, 141382) matched to TPs [507, 294]
# <Event, Hit Index> (73, 135678) matched to TPs [596, 566]
# <Event, Hit Index> (3, 7153) matched to TPs [664, 409]
# <Event, Hit Index> (81, 148410) matched to TPs [491, 244]
# <Event, Hit Index> (38, 70931) matched to TPs [248, 188]
# <Event, Hit Index> (5, 11733) matched to TPs [259, 231]
# <Event, Hit Index> (79, 144393) matched to TPs [865, 864]
# <Event, Hit Index> (42, 77884) matched to TPs [301, 219]
# <Event, Hit Index> (23, 46416) matched to TPs [533, 239]
# <Event, Hit Index> (77, 140981) matched to TPs [279, 243]
# <Event, Hit Index> (60, 112790) matched to TPs [800, 242]
# <Event, Hit Index> (3, 9424) matched to TPs [1224, 1222, 1219, 1217]
# <Event, Hit Index> (42, 79354) matched to TPs [1360, 1325]
# <Event, Hit Index> (54, 97892) matched to TPs [510, 509]
# <Event, Hit Index> (54, 98461) matched to TPs [1027, 143]
# <Event, Hit Index> (40, 74148) matched to TPs [266, 265]
# <Event, Hit Index> (3, 8345) matched to TPs [1188, 108]
# <Event, Hit Index> (21, 41726) matched to TPs [1061, 519]
# <Event, Hit Index> (74, 136601) matched to TPs [409, 140, 16]
# <Event, Hit Index> (46, 84314) matched to TPs [242, 160]
# <Event, Hit Index> (73, 135957) matched to TPs [891, 520]
# <Event, Hit Index> (39, 73134) matched to TPs [249, 177]
# <Event, Hit Index> (43, 80342) matched to TPs [83, 82]
# <Event, Hit Index> (11, 23872) matched to TPs [702, 99]
# <Event, Hit Index> (50, 92124) matched to TPs [559, 359]
# <Event, Hit Index> (22, 43288) matched to TPs [93, 17]
# <Event, Hit Index> (8, 18735) matched to TPs [656, 372]
# <Event, Hit Index> (98, 178616) matched to TPs [290, 289, 153]
# <Event, Hit Index> (73, 134687) matched to TPs [821, 176]
# <Event, Hit Index> (59, 110601) matched to TPs [806, 626]
# <Event, Hit Index> (20, 40220) matched to TPs [417, 416]
# <Event, Hit Index> (64, 118843) matched to TPs [887, 886, 184]
# <Event, Hit Index> (44, 81432) matched to TPs [302, 96]
# <Event, Hit Index> (95, 173174) matched to TPs [122, 10]
# <Event, Hit Index> (42, 78998) matched to TPs [818, 246]
# <Event, Hit Index> (33, 63645) matched to TPs [361, 336]
# <Event, Hit Index> (12, 25435) matched to TPs [417, 416]
# <Event, Hit Index> (11, 24434) matched to TPs [196, 182]
# <Event, Hit Index> (37, 70042) matched to TPs [281, 216]
# <Event, Hit Index> (50, 91053) matched to TPs [551, 544]
# <Event, Hit Index> (8, 18950) matched to TPs [239, 168, 79]
# <Event, Hit Index> (0, 480) matched to TPs [554, 553]
# <Event, Hit Index> (87, 159598) matched to TPs [854, 343]
# <Event, Hit Index> (6, 15900) matched to TPs [111, 61]
# <Event, Hit Index> (77, 140681) matched to TPs [632, 109]
# <Event, Hit Index> (22, 43923) matched to TPs [224, 144]
# <Event, Hit Index> (62, 115815) matched to TPs [246, 245]
# <Event, Hit Index> (60, 113605) matched to TPs [381, 151]
# <Event, Hit Index> (7, 16920) matched to TPs [130, 93]
# <Event, Hit Index> (98, 178256) matched to TPs [560, 519]
# <Event, Hit Index> (70, 130901) matched to TPs [521, 185]
# <Event, Hit Index> (48, 87492) matched to TPs [452, 451, 448]
# <Event, Hit Index> (23, 47822) matched to TPs [1019, 488]
# <Event, Hit Index> (25, 51726) matched to TPs [871, 276]
# <Event, Hit Index> (62, 115322) matched to TPs [512, 511]
# <Event, Hit Index> (10, 22237) matched to TPs [248, 247]
# <Event, Hit Index> (75, 137982) matched to TPs [167, 52]
# <Event, Hit Index> (39, 72453) matched to TPs [699, 217]
# <Event, Hit Index> (96, 174025) matched to TPs [114, 112]
# <Event, Hit Index> (55, 100775) matched to TPs [1267, 145]
# <Event, Hit Index> (97, 175941) matched to TPs [1053, 3]
# <Event, Hit Index> (49, 88865) matched to TPs [127, 7]
# <Event, Hit Index> (74, 137298) matched to TPs [145, 139]
# <Event, Hit Index> (72, 132916) matched to TPs [396, 395]
# <Event, Hit Index> (81, 147612) matched to TPs [789, 788]
# <Event, Hit Index> (58, 108716) matched to TPs [964, 562]
# <Event, Hit Index> (40, 75675) matched to TPs [1071, 265]
# <Event, Hit Index> (26, 53766) matched to TPs [301, 300]
# <Event, Hit Index> (29, 57470) matched to TPs [211, 191]
# <Event, Hit Index> (6, 14432) matched to TPs [684, 171]
# <Event, Hit Index> (20, 40155) matched to TPs [409, 128]
# <Event, Hit Index> (37, 70236) matched to TPs [242, 219]
# <Event, Hit Index> (93, 169120) matched to TPs [569, 568, 0]
# <Event, Hit Index> (30, 59942) matched to TPs [685, 494]
# <Event, Hit Index> (53, 97127) matched to TPs [805, 804]
# <Event, Hit Index> (28, 56740) matched to TPs [564, 562]
# <Event, Hit Index> (5, 11697) matched to TPs [654, 619]
# <Event, Hit Index> (47, 85965) matched to TPs [173, 170]
# <Event, Hit Index> (10, 23329) matched to TPs [537, 380]
# <Event, Hit Index> (7, 16706) matched to TPs [153, 66]
# <Event, Hit Index> (57, 105701) matched to TPs [1033, 974]
# <Event, Hit Index> (92, 168778) matched to TPs [551, 60]
# <Event, Hit Index> (84, 153140) matched to TPs [541, 335]
# <Event, Hit Index> (65, 121344) matched to TPs [164, 160]
# <Event, Hit Index> (15, 31836) matched to TPs [347, 346]
# <Event, Hit Index> (40, 73736) matched to TPs [805, 133]
# <Event, Hit Index> (51, 92552) matched to TPs [821, 42]
# <Event, Hit Index> (9, 21034) matched to TPs [386, 385]
# <Event, Hit Index> (14, 29337) matched to TPs [725, 724]
# <Event, Hit Index> (49, 89851) matched to TPs [503, 65]
# <Event, Hit Index> (94, 170713) matched to TPs [366, 85]
# <Event, Hit Index> (79, 143959) matched to TPs [299, 298]
# <Event, Hit Index> (87, 159347) matched to TPs [159, 0]
# <Event, Hit Index> (99, 179814) matched to TPs [297, 296]
# <Event, Hit Index> (41, 77423) matched to TPs [96, 26]
# <Event, Hit Index> (13, 26846) matched to TPs [144, 141]
# <Event, Hit Index> (32, 61991) matched to TPs [245, 74]
# <Event, Hit Index> (87, 160493) matched to TPs [813, 812]
# <Event, Hit Index> (23, 46386) matched to TPs [533, 532]
# <Event, Hit Index> (74, 137858) matched to TPs [508, 249]
# <Event, Hit Index> (7, 17973) matched to TPs [278, 129]
# <Event, Hit Index> (94, 170386) matched to TPs [158, 66]
# <Event, Hit Index> (46, 84633) matched to TPs [149, 148]
# <Event, Hit Index> (39, 72727) matched to TPs [629, 627]
# <Event, Hit Index> (39, 73021) matched to TPs [242, 203]
# <Event, Hit Index> (50, 91081) matched to TPs [733, 732]
# <Event, Hit Index> (21, 41161) matched to TPs [107, 100]
# <Event, Hit Index> (7, 16496) matched to TPs [206, 205]
# <Event, Hit Index> (57, 105263) matched to TPs [312, 36]
# <Event, Hit Index> (83, 151866) matched to TPs [652, 123]
# <Event, Hit Index> (84, 155148) matched to TPs [1042, 50]
# <Event, Hit Index> (3, 7367) matched to TPs [1329, 77]
# <Event, Hit Index> (4, 11052) matched to TPs [448, 447]
# <Event, Hit Index> (58, 107773) matched to TPs [816, 130]
# <Event, Hit Index> (10, 23358) matched to TPs [148, 23]
# <Event, Hit Index> (84, 152942) matched to TPs [404, 25]
# <Event, Hit Index> (15, 31144) matched to TPs [184, 156]
# <Event, Hit Index> (10, 22879) matched to TPs [503, 253]
# <Event, Hit Index> (24, 48414) matched to TPs [275, 271]
# <Event, Hit Index> (45, 83010) matched to TPs [208, 205]
# <Event, Hit Index> (82, 149405) matched to TPs [567, 558]
# <Event, Hit Index> (73, 134655) matched to TPs [899, 889]
# <Event, Hit Index> (73, 134801) matched to TPs [738, 112]
# <Event, Hit Index> (96, 174225) matched to TPs [442, 441]
# <Event, Hit Index> (50, 90686) matched to TPs [254, 204]
# <Event, Hit Index> (10, 22296) matched to TPs [665, 537, 24]
# <Event, Hit Index> (40, 74232) matched to TPs [728, 145]
# <Event, Hit Index> (81, 147662) matched to TPs [492, 491]
# <Event, Hit Index> (50, 92269) matched to TPs [580, 209]
# <Event, Hit Index> (57, 106290) matched to TPs [385, 100]
# <Event, Hit Index> (23, 46397) matched to TPs [1144, 407]
# <Event, Hit Index> (63, 116312) matched to TPs [613, 612]
# <Event, Hit Index> (44, 81984) matched to TPs [127, 12]
# <Event, Hit Index> (0, 1803) matched to TPs [847, 6]
# <Event, Hit Index> (9, 20449) matched to TPs [175, 137]
# <Event, Hit Index> (59, 110089) matched to TPs [56, 10]
# <Event, Hit Index> (10, 22539) matched to TPs [656, 76]
# <Event, Hit Index> (8, 18701) matched to TPs [223, 190]
# <Event, Hit Index> (66, 124534) matched to TPs [808, 271]
# <Event, Hit Index> (84, 151921) matched to TPs [1176, 188]
# <Event, Hit Index> (92, 167642) matched to TPs [116, 40]
# <Event, Hit Index> (21, 41552) matched to TPs [604, 603]
# <Event, Hit Index> (0, 1417) matched to TPs [305, 302]
# <Event, Hit Index> (26, 52878) matched to TPs [737, 736]
# <Event, Hit Index> (55, 101134) matched to TPs [898, 328]
# <Event, Hit Index> (26, 53381) matched to TPs [144, 102]
# <Event, Hit Index> (6, 15152) matched to TPs [879, 88]
# <Event, Hit Index> (93, 169310) matched to TPs [477, 476]
# <Event, Hit Index> (77, 141420) matched to TPs [598, 586]
# <Event, Hit Index> (96, 174026) matched to TPs [114, 112]
# <Event, Hit Index> (72, 132917) matched to TPs [396, 395]
# <Event, Hit Index> (11, 25180) matched to TPs [913, 845]
# <Event, Hit Index> (5, 11716) matched to TPs [980, 119]
# <Event, Hit Index> (19, 38650) matched to TPs [565, 564]
# <Event, Hit Index> (74, 136599) matched to TPs [409, 146]
# <Event, Hit Index> (5, 13405) matched to TPs [445, 334]
# <Event, Hit Index> (60, 111827) matched to TPs [171, 166]
# <Event, Hit Index> (11, 25311) matched to TPs [632, 103]
# <Event, Hit Index> (57, 106489) matched to TPs [1291, 227]
# <Event, Hit Index> (67, 127282) matched to TPs [433, 421]
# <Event, Hit Index> (10, 22956) matched to TPs [374, 70]
# <Event, Hit Index> (37, 70235) matched to TPs [220, 96]
# <Event, Hit Index> (0, 431) matched to TPs [299, 298]
# <Event, Hit Index> (33, 64218) matched to TPs [358, 357]
# <Event, Hit Index> (40, 73984) matched to TPs [770, 769]
# <Event, Hit Index> (29, 57332) matched to TPs [440, 439]
# <Event, Hit Index> (37, 68760) matched to TPs [200, 89]
# <Event, Hit Index> (1, 3986) matched to TPs [226, 206]
# <Event, Hit Index> (26, 52777) matched to TPs [800, 11]
# <Event, Hit Index> (58, 108526) matched to TPs [873, 129]
# <Event, Hit Index> (65, 122167) matched to TPs [207, 45]
# <Event, Hit Index> (57, 104873) matched to TPs [659, 195]
# <Event, Hit Index> (40, 73737) matched to TPs [805, 133]
# <Event, Hit Index> (50, 90480) matched to TPs [548, 247]
# <Event, Hit Index> (82, 150091) matched to TPs [737, 196]
# <Event, Hit Index> (82, 150462) matched to TPs [1009, 191]
# <Event, Hit Index> (38, 70381) matched to TPs [124, 1]
# <Event, Hit Index> (11, 23952) matched to TPs [360, 359]
# <Event, Hit Index> (0, 601) matched to TPs [373, 0]
# <Event, Hit Index> (84, 151906) matched to TPs [277, 7]
# <Event, Hit Index> (74, 137124) matched to TPs [341, 183]
# <Event, Hit Index> (56, 102944) matched to TPs [651, 414]
# <Event, Hit Index> (76, 140069) matched to TPs [342, 98]
# <Event, Hit Index> (93, 169685) matched to TPs [417, 416]
# <Event, Hit Index> (63, 118254) matched to TPs [735, 204]
# <Event, Hit Index> (19, 38604) matched to TPs [873, 279]
# <Event, Hit Index> (27, 54612) matched to TPs [894, 228]
# <Event, Hit Index> (72, 133816) matched to TPs [709, 130]
# <Event, Hit Index> (19, 38882) matched to TPs [871, 306]
# <Event, Hit Index> (7, 17025) matched to TPs [277, 93]
# <Event, Hit Index> (15, 31230) matched to TPs [415, 38]
# <Event, Hit Index> (17, 35347) matched to TPs [539, 433]
# <Event, Hit Index> (0, 568) matched to TPs [404, 403]
# <Event, Hit Index> (42, 77985) matched to TPs [131, 130]
# <Event, Hit Index> (84, 154408) matched to TPs [1324, 190]
# <Event, Hit Index> (64, 119039) matched to TPs [282, 281]
# <Event, Hit Index> (88, 162366) matched to TPs [445, 442]
# <Event, Hit Index> (81, 148377) matched to TPs [600, 583]
# <Event, Hit Index> (99, 179536) matched to TPs [154, 51]
# <Event, Hit Index> (42, 78786) matched to TPs [395, 235]
# <Event, Hit Index> (89, 163860) matched to TPs [316, 315]
# <Event, Hit Index> (14, 28268) matched to TPs [1257, 1256]
# <Event, Hit Index> (15, 31688) matched to TPs [122, 120]
# <Event, Hit Index> (73, 134621) matched to TPs [982, 322]
# <Event, Hit Index> (26, 53601) matched to TPs [202, 169]
# <Event, Hit Index> (84, 152818) matched to TPs [190, 51]
# <Event, Hit Index> (34, 65578) matched to TPs [302, 301]
# <Event, Hit Index> (62, 115103) matched to TPs [208, 207]
# <Event, Hit Index> (53, 96514) matched to TPs [214, 213]
# <Event, Hit Index> (89, 163724) matched to TPs [190, 124]
# <Event, Hit Index> (67, 127313) matched to TPs [433, 421]
# <Event, Hit Index> (82, 150508) matched to TPs [727, 726]
# <Event, Hit Index> (40, 74532) matched to TPs [679, 678]
# <Event, Hit Index> (72, 132771) matched to TPs [622, 619]
# <Event, Hit Index> (86, 158281) matched to TPs [186, 177]
# <Event, Hit Index> (5, 13968) matched to TPs [829, 539]
# <Event, Hit Index> (38, 70640) matched to TPs [672, 191]
# <Event, Hit Index> (11, 24397) matched to TPs [318, 84, 27]
# <Event, Hit Index> (47, 85376) matched to TPs [478, 472]
# <Event, Hit Index> (23, 46270) matched to TPs [983, 299]
# <Event, Hit Index> (42, 79453) matched to TPs [665, 626]
# <Event, Hit Index> (20, 39874) matched to TPs [520, 66]
# <Event, Hit Index> (56, 102929) matched to TPs [117, 27]
# <Event, Hit Index> (60, 113217) matched to TPs [990, 989, 988, 144]
# <Event, Hit Index> (89, 163284) matched to TPs [137, 81]
# <Event, Hit Index> (63, 116636) matched to TPs [203, 184]
# <Event, Hit Index> (77, 141002) matched to TPs [163, 101]
# <Event, Hit Index> (23, 46396) matched to TPs [370, 369, 314]
# <Event, Hit Index> (7, 17888) matched to TPs [278, 129]
# <Event, Hit Index> (40, 75030) matched to TPs [1132, 489]
# <Event, Hit Index> (10, 22453) matched to TPs [173, 145, 144]
# <Event, Hit Index> (6, 16039) matched to TPs [111, 61]
# <Event, Hit Index> (75, 138582) matched to TPs [73, 72]
# <Event, Hit Index> (67, 126584) matched to TPs [470, 104]
# <Event, Hit Index> (45, 83865) matched to TPs [130, 129]
# <Event, Hit Index> (10, 22191) matched to TPs [664, 538, 255]
# <Event, Hit Index> (50, 91592) matched to TPs [614, 484]
# <Event, Hit Index> (82, 150309) matched to TPs [887, 732]
# <Event, Hit Index> (55, 99689) matched to TPs [1080, 159]
# <Event, Hit Index> (87, 160769) matched to TPs [294, 194]
# <Event, Hit Index> (3, 6305) matched to TPs [1395, 1394]
# <Event, Hit Index> (44, 81952) matched to TPs [517, 509]
# <Event, Hit Index> (3, 9103) matched to TPs [958, 194]
# <Event, Hit Index> (38, 71294) matched to TPs [391, 390]
# <Event, Hit Index> (98, 177840) matched to TPs [92, 88]
# <Event, Hit Index> (40, 74731) matched to TPs [118, 23]
# <Event, Hit Index> (96, 174027) matched to TPs [115, 112]
# <Event, Hit Index> (97, 176880) matched to TPs [874, 533]
# <Event, Hit Index> (51, 92867) matched to TPs [494, 343]
# <Event, Hit Index> (28, 56169) matched to TPs [128, 84]
# <Event, Hit Index> (57, 104884) matched to TPs [9, 7]
# <Event, Hit Index> (34, 65668) matched to TPs [142, 92, 9]
# <Event, Hit Index> (10, 23078) matched to TPs [609, 110]
# <Event, Hit Index> (86, 158184) matched to TPs [400, 85]
# <Event, Hit Index> (72, 133139) matched to TPs [740, 739]
# <Event, Hit Index> (85, 155426) matched to TPs [180, 179]
# <Event, Hit Index> (94, 170487) matched to TPs [979, 885]
# <Event, Hit Index> (87, 159886) matched to TPs [804, 279]
# <Event, Hit Index> (97, 176955) matched to TPs [421, 85]
# <Event, Hit Index> (34, 65324) matched to TPs [587, 69]
# <Event, Hit Index> (39, 72580) matched to TPs [674, 23]
# <Event, Hit Index> (9, 20707) matched to TPs [120, 115]
# <Event, Hit Index> (6, 15655) matched to TPs [790, 113]
# <Event, Hit Index> (96, 175436) matched to TPs [392, 242]
# <Event, Hit Index> (52, 94496) matched to TPs [481, 153]
# <Event, Hit Index> (31, 60620) matched to TPs [127, 24]
# <Event, Hit Index> (47, 85491) matched to TPs [456, 395]
# <Event, Hit Index> (52, 95599) matched to TPs [568, 567]
# <Event, Hit Index> (5, 12626) matched to TPs [1046, 1044]
# <Event, Hit Index> (85, 155425) matched to TPs [829, 828]
# <Event, Hit Index> (0, 1727) matched to TPs [404, 2]
# <Event, Hit Index> (65, 121350) matched to TPs [166, 66]
# <Event, Hit Index> (57, 106937) matched to TPs [582, 421]
# <Event, Hit Index> (43, 80382) matched to TPs [187, 47]
# <Event, Hit Index> (29, 57480) matched to TPs [25, 18]
# <Event, Hit Index> (56, 103911) matched to TPs [391, 390]
# <Event, Hit Index> (38, 70711) matched to TPs [324, 30]
# <Event, Hit Index> (63, 116748) matched to TPs [482, 481]
# <Event, Hit Index> (30, 60080) matched to TPs [293, 220]
# <Event, Hit Index> (79, 143172) matched to TPs [1112, 380]
# <Event, Hit Index> (32, 62907) matched to TPs [400, 399]
# <Event, Hit Index> (53, 96281) matched to TPs [37, 36]
# <Event, Hit Index> (37, 70039) matched to TPs [574, 254, 207]
# <Event, Hit Index> (4, 9777) matched to TPs [101, 38]
# <Event, Hit Index> (96, 173992) matched to TPs [217, 216]
# <Event, Hit Index> (84, 152024) matched to TPs [264, 263]
# <Event, Hit Index> (51, 93240) matched to TPs [153, 150]
# <Event, Hit Index> (14, 30253) matched to TPs [924, 515, 454]
# <Event, Hit Index> (7, 17178) matched to TPs [533, 164]
# <Event, Hit Index> (86, 158594) matched to TPs [362, 361]
# <Event, Hit Index> (73, 134817) matched to TPs [183, 128]
# <Event, Hit Index> (14, 29427) matched to TPs [1093, 637]
# <Event, Hit Index> (47, 85036) matched to TPs [705, 178]
# <Event, Hit Index> (30, 58711) matched to TPs [196, 84]
# <Event, Hit Index> (64, 120507) matched to TPs [770, 570]
# <Event, Hit Index> (0, 498) matched to TPs [298, 214]
# <Event, Hit Index> (82, 150196) matched to TPs [1002, 798]
# <Event, Hit Index> (77, 140678) matched to TPs [63, 61]
# <Event, Hit Index> (40, 74599) matched to TPs [1049, 164]
# <Event, Hit Index> (55, 100575) matched to TPs [785, 214]
# <Event, Hit Index> (81, 146892) matched to TPs [255, 254]
# <Event, Hit Index> (95, 172602) matched to TPs [361, 290]
# <Event, Hit Index> (57, 105601) matched to TPs [421, 181]
# <Event, Hit Index> (68, 128724) matched to TPs [583, 430]
# <Event, Hit Index> (22, 43462) matched to TPs [187, 40]
# <Event, Hit Index> (85, 156746) matched to TPs [757, 534]
# <Event, Hit Index> (96, 175524) matched to TPs [314, 12]
# <Event, Hit Index> (6, 15274) matched to TPs [334, 333]
# <Event, Hit Index> (35, 66379) matched to TPs [214, 213]
# <Event, Hit Index> (8, 19249) matched to TPs [860, 37]
# <Event, Hit Index> (85, 156393) matched to TPs [252, 99]
# <Event, Hit Index> (38, 71653) matched to TPs [580, 577]
# <Event, Hit Index> (66, 124764) matched to TPs [1188, 308]
# <Event, Hit Index> (26, 52995) matched to TPs [458, 457]
# <Event, Hit Index> (42, 79218) matched to TPs [442, 441]
# <Event, Hit Index> (26, 52843) matched to TPs [437, 436]
# <Event, Hit Index> (40, 73905) matched to TPs [487, 486]
# <Event, Hit Index> (46, 84670) matched to TPs [149, 79]
# <Event, Hit Index> (27, 53938) matched to TPs [900, 899]
# <Event, Hit Index> (14, 28059) matched to TPs [309, 308]
# <Event, Hit Index> (26, 53780) matched to TPs [641, 101]
# <Event, Hit Index> (73, 134620) matched to TPs [983, 321]
# <Event, Hit Index> (12, 25510) matched to TPs [309, 89]
# <Event, Hit Index> (73, 136458) matched to TPs [856, 633]
# <Event, Hit Index> (88, 162334) matched to TPs [784, 13]
# <Event, Hit Index> (19, 39090) matched to TPs [324, 323]
# <Event, Hit Index> (57, 106787) matched to TPs [1032, 55]
# <Event, Hit Index> (92, 168380) matched to TPs [410, 409]
# <Event, Hit Index> (50, 90494) matched to TPs [1087, 516]
# <Event, Hit Index> (15, 31655) matched to TPs [563, 91]
# <Event, Hit Index> (2, 5101) matched to TPs [832, 231]
# <Event, Hit Index> (1, 2485) matched to TPs [418, 415]
# <Event, Hit Index> (98, 177870) matched to TPs [159, 33]
# <Event, Hit Index> (90, 165743) matched to TPs [520, 283]
# <Event, Hit Index> (65, 121313) matched to TPs [203, 170]
# <Event, Hit Index> (38, 70641) matched to TPs [672, 191, 88]
# <Event, Hit Index> (98, 178615) matched to TPs [594, 593]
# <Event, Hit Index> (17, 35787) matched to TPs [677, 94]
# <Event, Hit Index> (4, 10705) matched to TPs [736, 733]
# <Event, Hit Index> (16, 32615) matched to TPs [559, 558]
# <Event, Hit Index> (6, 14542) matched to TPs [405, 404]
# <Event, Hit Index> (34, 64462) matched to TPs [255, 254]
# <Event, Hit Index> (18, 36547) matched to TPs [172, 158]
# <Event, Hit Index> (20, 39875) matched to TPs [520, 66]
# <Event, Hit Index> (95, 172738) matched to TPs [656, 546]
# <Event, Hit Index> (47, 86012) matched to TPs [658, 489]
# <Event, Hit Index> (19, 38184) matched to TPs [410, 409]
# <Event, Hit Index> (5, 11887) matched to TPs [840, 837]
# <Event, Hit Index> (29, 57364) matched to TPs [604, 13]
# <Event, Hit Index> (7, 17453) matched to TPs [611, 610, 94]
# <Event, Hit Index> (34, 65218) matched to TPs [726, 72]
# <Event, Hit Index> (3, 6831) matched to TPs [917, 233]
# <Event, Hit Index> (77, 141144) matched to TPs [168, 48]
# <Event, Hit Index> (77, 141410) matched to TPs [246, 235]
# <Event, Hit Index> (0, 836) matched to TPs [530, 529]
# <Event, Hit Index> (50, 91122) matched to TPs [781, 780]
# <Event, Hit Index> (33, 63776) matched to TPs [238, 237]
# <Event, Hit Index> (79, 143612) matched to TPs [925, 472]
# <Event, Hit Index> (88, 161928) matched to TPs [491, 356]
# <Event, Hit Index> (90, 164324) matched to TPs [409, 408]
# <Event, Hit Index> (29, 57182) matched to TPs [169, 73]
# <Event, Hit Index> (26, 53379) matched to TPs [655, 34]
# <Event, Hit Index> (3, 9102) matched to TPs [958, 194]
# <Event, Hit Index> (29, 57854) matched to TPs [458, 399]
# <Event, Hit Index> (40, 74732) matched to TPs [782, 116]
# <Event, Hit Index> (79, 144242) matched to TPs [88, 3]
# <Event, Hit Index> (64, 119106) matched to TPs [144, 143]
# <Event, Hit Index> (77, 141038) matched to TPs [629, 16]
# <Event, Hit Index> (5, 13784) matched to TPs [939, 708]
# <Event, Hit Index> (8, 19605) matched to TPs [380, 379]
# <Event, Hit Index> (21, 42570) matched to TPs [840, 839]
# <Event, Hit Index> (26, 53765) matched to TPs [143, 36]
# <Event, Hit Index> (82, 149308) matched to TPs [179, 116]
# <Event, Hit Index> (74, 136597) matched to TPs [147, 144, 143]
# <Event, Hit Index> (45, 82193) matched to TPs [217, 216]
# <Event, Hit Index> (55, 101874) matched to TPs [782, 319]
# <Event, Hit Index> (49, 89601) matched to TPs [198, 197]
# <Event, Hit Index> (94, 170903) matched to TPs [1008, 179]
# <Event, Hit Index> (15, 32276) matched to TPs [471, 461, 459]
# <Event, Hit Index> (96, 174448) matched to TPs [667, 96]
# <Event, Hit Index> (50, 91531) matched to TPs [430, 429]
# <Event, Hit Index> (11, 24001) matched to TPs [694, 99, 98]
# <Event, Hit Index> (68, 128688) matched to TPs [127, 124]
# <Event, Hit Index> (21, 42569) matched to TPs [841, 839]
# <Event, Hit Index> (63, 117605) matched to TPs [831, 830]
# <Event, Hit Index> (64, 119965) matched to TPs [850, 849]
# <Event, Hit Index> (84, 153077) matched to TPs [1237, 70]
# <Event, Hit Index> (0, 1220) matched to TPs [772, 227]
# <Event, Hit Index> (68, 127871) matched to TPs [486, 78]
# <Event, Hit Index> (39, 73051) matched to TPs [516, 515]
# <Event, Hit Index> (55, 100105) matched to TPs [371, 290]
# <Event, Hit Index> (98, 179203) matched to TPs [688, 560]
# <Event, Hit Index> (47, 85490) matched to TPs [456, 395]
# <Event, Hit Index> (80, 146711) matched to TPs [253, 129]
# <Event, Hit Index> (53, 96529) matched to TPs [213, 129]
# <Event, Hit Index> (27, 54826) matched to TPs [299, 298]
# <Event, Hit Index> (76, 139350) matched to TPs [128, 98]
# <Event, Hit Index> (87, 159348) matched to TPs [159, 0]
# <Event, Hit Index> (28, 56504) matched to TPs [617, 167]
# <Event, Hit Index> (73, 135851) matched to TPs [330, 329]
# <Event, Hit Index> (31, 60588) matched to TPs [106, 105]
# <Event, Hit Index> (10, 23154) matched to TPs [194, 177]
# <Event, Hit Index> (62, 115418) matched to TPs [154, 153, 152]
# <Event, Hit Index> (43, 80368) matched to TPs [270, 269, 0]
# <Event, Hit Index> (20, 40370) matched to TPs [151, 148]
# <Event, Hit Index> (58, 108408) matched to TPs [733, 157]
# <Event, Hit Index> (51, 93118) matched to TPs [151, 149]
# <Event, Hit Index> (20, 39621) matched to TPs [393, 392]
# <Event, Hit Index> (3, 7648) matched to TPs [1035, 295]
# <Event, Hit Index> (80, 145822) matched to TPs [159, 24]
# <Event, Hit Index> (71, 131987) matched to TPs [626, 524]
# <Event, Hit Index> (54, 97565) matched to TPs [254, 185]
# <Event, Hit Index> (23, 46415) matched to TPs [895, 532]
# <Event, Hit Index> (40, 75015) matched to TPs [791, 23]
# <Event, Hit Index> (15, 32294) matched to TPs [365, 364]
# <Event, Hit Index> (73, 135002) matched to TPs [263, 262]
# <Event, Hit Index> (0, 499) matched to TPs [262, 214]
# <Event, Hit Index> (40, 74749) matched to TPs [492, 25]
# <Event, Hit Index> (19, 39168) matched to TPs [670, 2]
# <Event, Hit Index> (92, 168465) matched to TPs [511, 240]
# <Event, Hit Index> (45, 83069) matched to TPs [854, 727]
# <Event, Hit Index> (85, 156022) matched to TPs [162, 161]
# <Event, Hit Index> (18, 36082) matched to TPs [215, 168]
# <Event, Hit Index> (53, 97074) matched to TPs [647, 372]
# <Event, Hit Index> (54, 98573) matched to TPs [975, 241]
# <Event, Hit Index> (89, 163634) matched to TPs [433, 432]
# <Event, Hit Index> (7, 17873) matched to TPs [199, 182]
# <Event, Hit Index> (8, 19484) matched to TPs [231, 226]
# <Event, Hit Index> (19, 38217) matched to TPs [780, 40]
# <Event, Hit Index> (9, 21097) matched to TPs [370, 361]
# <Event, Hit Index> (5, 13023) matched to TPs [499, 498]
# <Event, Hit Index> (90, 164581) matched to TPs [623, 341, 340]
# <Event, Hit Index> (73, 136404) matched to TPs [598, 68]
# <Event, Hit Index> (38, 71450) matched to TPs [443, 438]
# <Event, Hit Index> (8, 20345) matched to TPs [927, 236]
# <Event, Hit Index> (32, 63137) matched to TPs [553, 471]
# <Event, Hit Index> (87, 159992) matched to TPs [530, 68]
# <Event, Hit Index> (99, 179538) matched to TPs [153, 50]
# <Event, Hit Index> (25, 50875) matched to TPs [872, 866]
# <Event, Hit Index> (54, 97511) matched to TPs [252, 248]
# <Event, Hit Index> (9, 21136) matched to TPs [442, 47]
# <Event, Hit Index> (96, 174202) matched to TPs [571, 570]
# <Event, Hit Index> (3, 9042) matched to TPs [1329, 1308]
# <Event, Hit Index> (93, 170190) matched to TPs [402, 8]
# <Event, Hit Index> (91, 166378) matched to TPs [169, 41]
# <Event, Hit Index> (11, 24890) matched to TPs [911, 846]
# <Event, Hit Index> (64, 119078) matched to TPs [69, 21]
# <Event, Hit Index> (87, 159748) matched to TPs [177, 50]
# <Event, Hit Index> (87, 160589) matched to TPs [542, 541]
# <Event, Hit Index> (26, 53755) matched to TPs [681, 292]
# <Event, Hit Index> (73, 136468) matched to TPs [826, 180]
# <Event, Hit Index> (23, 47467) matched to TPs [529, 196]
# <Event, Hit Index> (81, 146798) matched to TPs [114, 111]
# <Event, Hit Index> (42, 78204) matched to TPs [618, 256]
# <Event, Hit Index> (70, 130926) matched to TPs [208, 207]
# <Event, Hit Index> (77, 141978) matched to TPs [551, 76]
# <Event, Hit Index> (60, 111670) matched to TPs [121, 37]
# <Event, Hit Index> (73, 134716) matched to TPs [983, 806, 614, 613]
# <Event, Hit Index> (57, 104507) matched to TPs [1081, 206]
# <Event, Hit Index> (29, 57827) matched to TPs [595, 127]
# <Event, Hit Index> (53, 96578) matched to TPs [338, 45]
# <Event, Hit Index> (70, 129942) matched to TPs [609, 80]
# <Event, Hit Index> (2, 4842) matched to TPs [230, 104]
# <Event, Hit Index> (88, 161929) matched to TPs [333, 275]
# <Event, Hit Index> (15, 31507) matched to TPs [685, 36]
# <Event, Hit Index> (0, 1329) matched to TPs [668, 46]
# <Event, Hit Index> (79, 143829) matched to TPs [863, 292]
# <Event, Hit Index> (6, 14925) matched to TPs [415, 414]
# <Event, Hit Index> (88, 161698) matched to TPs [81, 31]
# <Event, Hit Index> (82, 149572) matched to TPs [961, 795]
# <Event, Hit Index> (73, 134736) matched to TPs [892, 890]
# <Event, Hit Index> (78, 142105) matched to TPs [220, 36]
# <Event, Hit Index> (74, 137104) matched to TPs [506, 420]
# <Event, Hit Index> (62, 115429) matched to TPs [396, 395]
# <Event, Hit Index> (56, 104330) matched to TPs [309, 308]
# <Event, Hit Index> (15, 32012) matched to TPs [179, 2]
# <Event, Hit Index> (4, 9729) matched to TPs [100, 99]
# <Event, Hit Index> (64, 119107) matched to TPs [144, 143]
# <Event, Hit Index> (77, 141037) matched to TPs [629, 16]
# <Event, Hit Index> (50, 91283) matched to TPs [937, 108]
# <Event, Hit Index> (91, 166888) matched to TPs [265, 21]
# <Event, Hit Index> (85, 155311) matched to TPs [70, 6]
# <Event, Hit Index> (34, 65666) matched to TPs [272, 171]
# <Event, Hit Index> (17, 35713) matched to TPs [691, 677]
# <Event, Hit Index> (96, 174187) matched to TPs [562, 429]
# <Event, Hit Index> (76, 139945) matched to TPs [342, 92]
# <Event, Hit Index> (47, 85468) matched to TPs [391, 76]
# <Event, Hit Index> (10, 22955) matched to TPs [506, 373]
# <Event, Hit Index> (6, 14477) matched to TPs [53, 52]
# <Event, Hit Index> (96, 174449) matched to TPs [667, 96]
# <Event, Hit Index> (37, 69123) matched to TPs [204, 203]
# <Event, Hit Index> (73, 136131) matched to TPs [891, 87]
# <Event, Hit Index> (42, 77580) matched to TPs [264, 229, 37]
# <Event, Hit Index> (75, 138409) matched to TPs [59, 34]
# <Event, Hit Index> (87, 159880) matched to TPs [192, 176]
# <Event, Hit Index> (25, 51121) matched to TPs [365, 31]
# <Event, Hit Index> (0, 474) matched to TPs [957, 48]
# <Event, Hit Index> (73, 136031) matched to TPs [413, 170]
# <Event, Hit Index> (5, 12600) matched to TPs [1054, 100]
# <Event, Hit Index> (5, 12390) matched to TPs [264, 262]
# <Event, Hit Index> (52, 93993) matched to TPs [623, 93]
# <Event, Hit Index> (15, 31533) matched to TPs [264, 263]
# <Event, Hit Index> (55, 99744) matched to TPs [375, 374, 372, 371, 368, 367, 366, 365, 330]
# <Event, Hit Index> (86, 157600) matched to TPs [172, 166]
# <Event, Hit Index> (95, 172865) matched to TPs [361, 95]
# <Event, Hit Index> (47, 85875) matched to TPs [720, 719, 71]
# <Event, Hit Index> (90, 165341) matched to TPs [494, 493]
# <Event, Hit Index> (93, 169364) matched to TPs [139, 10]
# <Event, Hit Index> (51, 92925) matched to TPs [326, 325]
# <Event, Hit Index> (62, 115419) matched to TPs [154, 153, 152]
# <Event, Hit Index> (42, 77659) matched to TPs [808, 807, 225]
# <Event, Hit Index> (30, 60153) matched to TPs [293, 238]
# <Event, Hit Index> (70, 129959) matched to TPs [191, 186, 185]
# <Event, Hit Index> (56, 103549) matched to TPs [657, 23]
# <Event, Hit Index> (87, 160078) matched to TPs [338, 337]
# <Event, Hit Index> (58, 107821) matched to TPs [721, 720]
# <Event, Hit Index> (46, 84531) matched to TPs [79, 75]
# <Event, Hit Index> (0, 1218) matched to TPs [658, 46]
# <Event, Hit Index> (20, 40461) matched to TPs [149, 84]
# <Event, Hit Index> (65, 121297) matched to TPs [505, 504, 44]
# <Event, Hit Index> (90, 165026) matched to TPs [136, 91]
# <Event, Hit Index> (59, 110650) matched to TPs [552, 551]
# <Event, Hit Index> (10, 22230) matched to TPs [178, 26]
# <Event, Hit Index> (10, 22109) matched to TPs [473, 176]
# <Event, Hit Index> (25, 51066) matched to TPs [385, 374]
# <Event, Hit Index> (5, 12782) matched to TPs [539, 538]
# <Event, Hit Index> (73, 135701) matched to TPs [480, 68]
# <Event, Hit Index> (41, 76547) matched to TPs [442, 436]
# <Event, Hit Index> (39, 72549) matched to TPs [590, 229]
# <Event, Hit Index> (14, 29793) matched to TPs [803, 297]
# <Event, Hit Index> (16, 33156) matched to TPs [695, 693]
# <Event, Hit Index> (84, 155086) matched to TPs [1357, 1336, 1017]
# <Event, Hit Index> (48, 87561) matched to TPs [692, 681]
# <Event, Hit Index> (66, 124103) matched to TPs [214, 85]
# <Event, Hit Index> (96, 174589) matched to TPs [214, 213]
# <Event, Hit Index> (33, 64292) matched to TPs [341, 90]
# <Event, Hit Index> (94, 170353) matched to TPs [140, 139]
# <Event, Hit Index> (94, 171867) matched to TPs [1038, 464]
# <Event, Hit Index> (6, 15051) matched to TPs [791, 507]
# <Event, Hit Index> (67, 127218) matched to TPs [324, 0]
# <Event, Hit Index> (54, 97780) matched to TPs [356, 185]
# <Event, Hit Index> (55, 99885) matched to TPs [325, 218]
# <Event, Hit Index> (29, 57250) matched to TPs [185, 154]
# <Event, Hit Index> (38, 71014) matched to TPs [182, 88]
# <Event, Hit Index> (79, 142992) matched to TPs [224, 36]
# <Event, Hit Index> (84, 154992) matched to TPs [1369, 816]
# <Event, Hit Index> (0, 434) matched to TPs [223, 45]
# <Event, Hit Index> (73, 135202) matched to TPs [75, 6]
# <Event, Hit Index> (30, 60079) matched to TPs [294, 237]
# <Event, Hit Index> (72, 132774) matched to TPs [624, 621]
# <Event, Hit Index> (58, 108276) matched to TPs [763, 190]
# <Event, Hit Index> (15, 31819) matched to TPs [196, 155]
# <Event, Hit Index> (64, 119309) matched to TPs [312, 311]
# <Event, Hit Index> (55, 100709) matched to TPs [1335, 255]
# <Event, Hit Index> (2, 5099) matched to TPs [694, 333]
# <Event, Hit Index> (3, 8445) matched to TPs [1379, 1378]
# <Event, Hit Index> (63, 118094) matched to TPs [281, 220]
# <Event, Hit Index> (42, 78490) matched to TPs [1089, 258]
# <Event, Hit Index> (3, 6732) matched to TPs [288, 49]
# <Event, Hit Index> (1, 2304) matched to TPs [184, 93]
# <Event, Hit Index> (78, 142509) matched to TPs [210, 206]
# <Event, Hit Index> (65, 121212) matched to TPs [1130, 50]
# <Event, Hit Index> (29, 57249) matched to TPs [185, 154]
# <Event, Hit Index> (25, 52093) matched to TPs [790, 789]
# <Event, Hit Index> (73, 134658) matched to TPs [895, 321]
# <Event, Hit Index> (32, 62152) matched to TPs [622, 93]
# <Event, Hit Index> (5, 12946) matched to TPs [326, 269]
# <Event, Hit Index> (65, 122021) matched to TPs [975, 129]
# <Event, Hit Index> (73, 135892) matched to TPs [907, 898]
# <Event, Hit Index> (58, 108032) matched to TPs [877, 129]
# <Event, Hit Index> (26, 52621) matched to TPs [210, 169]
# <Event, Hit Index> (23, 47216) matched to TPs [1011, 1008]
# <Event, Hit Index> (32, 62214) matched to TPs [184, 169]
# <Event, Hit Index> (39, 72829) matched to TPs [464, 463]
# <Event, Hit Index> (43, 80667) matched to TPs [285, 284, 0]
# <Event, Hit Index> (69, 129378) matched to TPs [373, 372]
# <Event, Hit Index> (40, 75033) matched to TPs [855, 852]
# <Event, Hit Index> (29, 57884) matched to TPs [597, 347]
# <Event, Hit Index> (34, 64420) matched to TPs [592, 591]
# <Event, Hit Index> (54, 99143) matched to TPs [410, 409]
# <Event, Hit Index> (58, 109282) matched to TPs [312, 311]
# <Event, Hit Index> (27, 53958) matched to TPs [971, 755]
# <Event, Hit Index> (56, 102963) matched to TPs [143, 142]
# <Event, Hit Index> (86, 158469) matched to TPs [556, 67]
# <Event, Hit Index> (31, 61318) matched to TPs [349, 347]
# <Event, Hit Index> (72, 134081) matched to TPs [693, 601]
# <Event, Hit Index> (41, 77291) matched to TPs [449, 25]
# <Event, Hit Index> (67, 126929) matched to TPs [221, 220]
# <Event, Hit Index> (10, 22691) matched to TPs [436, 36]
# <Event, Hit Index> (5, 13393) matched to TPs [421, 333]
# <Event, Hit Index> (23, 46599) matched to TPs [796, 127]
# <Event, Hit Index> (65, 121814) matched to TPs [202, 24]
# <Event, Hit Index> (51, 93291) matched to TPs [55, 3]
# <Event, Hit Index> (51, 92868) matched to TPs [494, 343]
# <Event, Hit Index> (55, 101000) matched to TPs [1263, 298]
# <Event, Hit Index> (34, 65667) matched to TPs [272, 171]
# <Event, Hit Index> (5, 12207) matched to TPs [560, 266]
# <Event, Hit Index> (20, 40160) matched to TPs [409, 36]
# <Event, Hit Index> (48, 87609) matched to TPs [646, 645]
# <Event, Hit Index> (94, 172384) matched to TPs [831, 830]
# <Event, Hit Index> (73, 134213) matched to TPs [848, 25]
# <Event, Hit Index> (76, 139913) matched to TPs [701, 700]
# <Event, Hit Index> (38, 70596) matched to TPs [657, 485]
# <Event, Hit Index> (55, 100278) matched to TPs [1330, 148]
# <Event, Hit Index> (68, 127865) matched to TPs [487, 35]
# <Event, Hit Index> (42, 77832) matched to TPs [1086, 186]
# <Event, Hit Index> (11, 24532) matched to TPs [89, 86]
# <Event, Hit Index> (7, 17370) matched to TPs [300, 294, 0]
# <Event, Hit Index> (15, 32375) matched to TPs [720, 80]
# <Event, Hit Index> (67, 126895) matched to TPs [511, 58]
# <Event, Hit Index> (10, 22168) matched to TPs [62, 60]
# <Event, Hit Index> (9, 21592) matched to TPs [161, 145]
# <Event, Hit Index> (56, 103636) matched to TPs [146, 141]
# <Event, Hit Index> (22, 44026) matched to TPs [105, 84]
# <Event, Hit Index> (4, 10059) matched to TPs [529, 207]
# <Event, Hit Index> (72, 132673) matched to TPs [159, 131]
# <Event, Hit Index> (23, 48009) matched to TPs [139, 23]
# <Event, Hit Index> (45, 82534) matched to TPs [762, 308]
# <Event, Hit Index> (84, 152854) matched to TPs [175, 53]
# <Event, Hit Index> (87, 160721) matched to TPs [666, 359]
# <Event, Hit Index> (76, 139593) matched to TPs [711, 7]
# <Event, Hit Index> (75, 138586) matched to TPs [362, 141]
# <Event, Hit Index> (7, 17088) matched to TPs [278, 130]
# <Event, Hit Index> (30, 59058) matched to TPs [191, 38]
# <Event, Hit Index> (77, 140840) matched to TPs [514, 67]
# <Event, Hit Index> (3, 6816) matched to TPs [1350, 233]
# <Event, Hit Index> (84, 154666) matched to TPs [760, 27]
# <Event, Hit Index> (49, 89568) matched to TPs [375, 131]
# <Event, Hit Index> (42, 79138) matched to TPs [1319, 298]
# ...
# <Event, Hit Index> (84, 152032) matched to TPs [716, 715, 278]
# <Event, Hit Index> (55, 99743) matched to TPs [371, 76]
# <Event, Hit Index> (90, 165215) matched to TPs [426, 6]
# <Event, Hit Index> (56, 103231) matched to TPs [177, 176, 174, 173, 172]
# <Event, Hit Index> (39, 72808) matched to TPs [673, 595]
# <Event, Hit Index> (76, 139700) matched to TPs [555, 490]
# <Event, Hit Index> (14, 29435) matched to TPs [355, 354, 254]
# <Event, Hit Index> (43, 80635) matched to TPs [225, 146]
# <Event, Hit Index> (66, 125876) matched to TPs [1062, 196]
# <Event, Hit Index> (50, 90632) matched to TPs [881, 214]
# <Event, Hit Index> (3, 7162) matched to TPs [1162, 664]
# <Event, Hit Index> (65, 123016) matched to TPs [289, 288]
# <Event, Hit Index> (48, 88199) matched to TPs [680, 78]
# <Event, Hit Index> (10, 23454) matched to TPs [291, 111]
# <Event, Hit Index> (21, 41591) matched to TPs [170, 144]
# <Event, Hit Index> (74, 136557) matched to TPs [6, 3]
# <Event, Hit Index> (98, 178573) matched to TPs [186, 185]
# <Event, Hit Index> (39, 71915) matched to TPs [229, 89]
# <Event, Hit Index> (44, 81928) matched to TPs [127, 12]
# <Event, Hit Index> (10, 22489) matched to TPs [461, 420]
# <Event, Hit Index> (88, 161617) matched to TPs [491, 111]
# <Event, Hit Index> (73, 136388) matched to TPs [636, 633, 579]
# <Event, Hit Index> (52, 94724) matched to TPs [205, 145]
# <Event, Hit Index> (75, 138245) matched to TPs [372, 144]
# <Event, Hit Index> (73, 136311) matched to TPs [984, 890]
# <Event, Hit Index> (33, 64192) matched to TPs [340, 132]
# <Event, Hit Index> (75, 138445) matched to TPs [276, 275]
# <Event, Hit Index> (29, 57465) matched to TPs [595, 187]
# <Event, Hit Index> (70, 130180) matched to TPs [191, 186]
# <Event, Hit Index> (84, 152160) matched to TPs [173, 171, 163]
# <Event, Hit Index> (52, 95467) matched to TPs [481, 258]
# <Event, Hit Index> (68, 128347) matched to TPs [502, 480, 476]
# <Event, Hit Index> (87, 159349) matched to TPs [159, 0]
# <Event, Hit Index> (7, 17023) matched to TPs [278, 277, 129]
# <Event, Hit Index> (97, 177449) matched to TPs [986, 719]
# <Event, Hit Index> (87, 159647) matched to TPs [602, 162]
# <Event, Hit Index> (57, 104658) matched to TPs [311, 1]
# <Event, Hit Index> (25, 51309) matched to TPs [418, 77]
# <Event, Hit Index> (60, 111422) matched to TPs [517, 516]
# <Event, Hit Index> (86, 157961) matched to TPs [580, 77, 9]
# <Event, Hit Index> (37, 70009) matched to TPs [351, 176]
# <Event, Hit Index> (73, 134660) matched to TPs [950, 900, 322]
# <Event, Hit Index> (76, 139607) matched to TPs [511, 319]
# <Event, Hit Index> (40, 75040) matched to TPs [850, 782]
# <Event, Hit Index> (35, 66087) matched to TPs [127, 78]
# <Event, Hit Index> (24, 48594) matched to TPs [254, 232]
# <Event, Hit Index> (51, 93235) matched to TPs [381, 380, 185]
# <Event, Hit Index> (67, 126437) matched to TPs [510, 59]
# <Event, Hit Index> (70, 130687) matched to TPs [262, 261]
# <Event, Hit Index> (50, 90393) matched to TPs [105, 25]
# <Event, Hit Index> (3, 6452) matched to TPs [1351, 237]
# <Event, Hit Index> (0, 352) matched to TPs [227, 226]
# <Event, Hit Index> (73, 136393) matched to TPs [330, 180]
# <Event, Hit Index> (66, 125861) matched to TPs [994, 130]
# <Event, Hit Index> (2, 4422) matched to TPs [616, 189]
# <Event, Hit Index> (85, 155768) matched to TPs [215, 35]
# <Event, Hit Index> (64, 119361) matched to TPs [519, 518]
# <Event, Hit Index> (89, 163350) matched to TPs [105, 101]
# <Event, Hit Index> (4, 9707) matched to TPs [69, 56]
# <Event, Hit Index> (76, 140020) matched to TPs [535, 94]
# <Event, Hit Index> (43, 80619) matched to TPs [72, 28]
# <Event, Hit Index> (38, 71287) matched to TPs [391, 390]
# <Event, Hit Index> (56, 103942) matched to TPs [348, 347]
# <Event, Hit Index> (78, 142415) matched to TPs [240, 238, 237, 220]
# <Event, Hit Index> (15, 32021) matched to TPs [432, 179]
# <Event, Hit Index> (50, 91274) matched to TPs [925, 924]
# <Event, Hit Index> (77, 140827) matched to TPs [639, 109]
# <Event, Hit Index> (1, 2758) matched to TPs [781, 156]
# <Event, Hit Index> (34, 65366) matched to TPs [211, 171]
# <Event, Hit Index> (39, 72836) matched to TPs [428, 427]
# <Event, Hit Index> (74, 136605) matched to TPs [149, 17]
# <Event, Hit Index> (24, 49080) matched to TPs [1032, 1027]
# <Event, Hit Index> (10, 22473) matched to TPs [645, 145]
# <Event, Hit Index> (8, 18723) matched to TPs [251, 32]
# <Event, Hit Index> (73, 135183) matched to TPs [1026, 494]
# <Event, Hit Index> (59, 109552) matched to TPs [5, 4]
# <Event, Hit Index> (4, 10899) matched to TPs [758, 741]
# <Event, Hit Index> (73, 134223) matched to TPs [983, 73]
# <Event, Hit Index> (0, 1089) matched to TPs [1021, 135]
# <Event, Hit Index> (37, 69827) matched to TPs [516, 515]
# <Event, Hit Index> (79, 143935) matched to TPs [285, 284]
# <Event, Hit Index> (10, 22639) matched to TPs [653, 8]
# <Event, Hit Index> (53, 96859) matched to TPs [422, 148]
# <Event, Hit Index> (78, 142265) matched to TPs [107, 106]
# <Event, Hit Index> (75, 138450) matched to TPs [392, 387]
# <Event, Hit Index> (20, 39601) matched to TPs [108, 62]
# <Event, Hit Index> (58, 108155) matched to TPs [567, 566]
# <Event, Hit Index> (55, 100453) matched to TPs [826, 54]
# <Event, Hit Index> (74, 136964) matched to TPs [281, 123]
# <Event, Hit Index> (6, 14788) matched to TPs [622, 201]
# <Event, Hit Index> (78, 142356) matched to TPs [178, 71]
# <Event, Hit Index> (73, 135874) matched to TPs [338, 337, 299, 298, 296, 196, 154]
# <Event, Hit Index> (41, 75978) matched to TPs [198, 157]
# <Event, Hit Index> (4, 11237) matched to TPs [543, 207]
# <Event, Hit Index> (96, 175337) matched to TPs [665, 342]
# <Event, Hit Index> (31, 61219) matched to TPs [199, 198]
# <Event, Hit Index> (63, 116566) matched to TPs [427, 426]
# <Event, Hit Index> (32, 62777) matched to TPs [385, 306]
# <Event, Hit Index> (62, 115816) matched to TPs [249, 248]
# <Event, Hit Index> (44, 81855) matched to TPs [114, 12]
# <Event, Hit Index> (68, 127689) matched to TPs [480, 35]
# <Event, Hit Index> (63, 117037) matched to TPs [966, 433]
# <Event, Hit Index> (8, 19431) matched to TPs [986, 985]
# <Event, Hit Index> (3, 9128) matched to TPs [944, 312]
# <Event, Hit Index> (65, 122789) matched to TPs [897, 896]
# <Event, Hit Index> (38, 71205) matched to TPs [348, 187]
# <Event, Hit Index> (22, 44142) matched to TPs [777, 776]
# <Event, Hit Index> (84, 153291) matched to TPs [640, 110]
# <Event, Hit Index> (37, 69326) matched to TPs [752, 197]
# <Event, Hit Index> (14, 29984) matched to TPs [611, 496]
# <Event, Hit Index> (1, 3250) matched to TPs [216, 201]
# <Event, Hit Index> (64, 119757) matched to TPs [237, 142]
# <Event, Hit Index> (36, 67773) matched to TPs [449, 447]
# <Event, Hit Index> (6, 14603) matched to TPs [126, 50]
# <Event, Hit Index> (11, 23979) matched to TPs [386, 293]
# <Event, Hit Index> (87, 159955) matched to TPs [510, 68]
# <Event, Hit Index> (10, 21886) matched to TPs [108, 107]
# <Event, Hit Index> (60, 112418) matched to TPs [714, 194]
# <Event, Hit Index> (10, 23455) matched to TPs [681, 154]
# <Event, Hit Index> (19, 38762) matched to TPs [524, 123]
# <Event, Hit Index> (40, 75107) matched to TPs [52, 8]
# <Event, Hit Index> (44, 81929) matched to TPs [127, 12]
# <Event, Hit Index> (84, 154968) matched to TPs [1018, 606]
# <Event, Hit Index> (96, 174457) matched to TPs [393, 392]
# <Event, Hit Index> (94, 170630) matched to TPs [239, 153]
# <Event, Hit Index> (43, 80468) matched to TPs [187, 78]
# <Event, Hit Index> (23, 47000) matched to TPs [448, 243]
# <Event, Hit Index> (73, 135878) matched to TPs [170, 154]
# <Event, Hit Index> (7, 16485) matched to TPs [413, 140]
# <Event, Hit Index> (58, 108834) matched to TPs [990, 988]
# <Event, Hit Index> (35, 67153) matched to TPs [363, 362]
# <Event, Hit Index> (0, 902) matched to TPs [122, 49]
# <Event, Hit Index> (10, 21777) matched to TPs [125, 56]
# <Event, Hit Index> (90, 165390) matched to TPs [521, 187]
# <Event, Hit Index> (5, 13866) matched to TPs [132, 122]
# <Event, Hit Index> (11, 24889) matched to TPs [914, 913]
# <Event, Hit Index> (96, 175286) matched to TPs [333, 65]
# <Event, Hit Index> (14, 28975) matched to TPs [1153, 219]
# <Event, Hit Index> (34, 65568) matched to TPs [620, 304]
# <Event, Hit Index> (30, 59441) matched to TPs [489, 488]
# <Event, Hit Index> (97, 175852) matched to TPs [428, 427]
# <Event, Hit Index> (11, 23932) matched to TPs [705, 694]
# <Event, Hit Index> (50, 91571) matched to TPs [228, 136]
# <Event, Hit Index> (34, 64745) matched to TPs [360, 37]
# <Event, Hit Index> (74, 137701) matched to TPs [606, 605]
# <Event, Hit Index> (74, 137112) matched to TPs [189, 146, 18]
# <Event, Hit Index> (54, 98632) matched to TPs [593, 592]
# <Event, Hit Index> (6, 15628) matched to TPs [435, 431]
# <Event, Hit Index> (22, 43699) matched to TPs [108, 29]
# <Event, Hit Index> (48, 87090) matched to TPs [599, 161]
# <Event, Hit Index> (55, 101798) matched to TPs [1247, 1093]
# <Event, Hit Index> (35, 66439) matched to TPs [341, 340]
# <Event, Hit Index> (26, 53469) matched to TPs [84, 37]
# <Event, Hit Index> (76, 139600) matched to TPs [6, 5]
# <Event, Hit Index> (41, 76880) matched to TPs [775, 2]
# <Event, Hit Index> (63, 118433) matched to TPs [244, 2]
# <Event, Hit Index> (60, 113442) matched to TPs [323, 258]
# <Event, Hit Index> (57, 106291) matched to TPs [385, 100]
# <Event, Hit Index> (10, 22194) matched to TPs [660, 503]
# <Event, Hit Index> (8, 20287) matched to TPs [897, 292]
# <Event, Hit Index> (28, 56125) matched to TPs [620, 117]
# <Event, Hit Index> (87, 160203) matched to TPs [327, 326]
# <Event, Hit Index> (73, 135559) matched to TPs [247, 182]
# <Event, Hit Index> (82, 149363) matched to TPs [983, 982, 981, 980, 18]
# <Event, Hit Index> (87, 160618) matched to TPs [667, 666]
# <Event, Hit Index> (70, 130247) matched to TPs [192, 155]
# <Event, Hit Index> (62, 115160) matched to TPs [368, 92]
# <Event, Hit Index> (70, 130482) matched to TPs [242, 66]
# <Event, Hit Index> (85, 156120) matched to TPs [745, 728]
# <Event, Hit Index> (20, 39645) matched to TPs [320, 61]
# <Event, Hit Index> (40, 73964) matched to TPs [255, 143]
# <Event, Hit Index> (92, 167879) matched to TPs [513, 508]
# <Event, Hit Index> (74, 136769) matched to TPs [184, 183, 150]
# <Event, Hit Index> (79, 145069) matched to TPs [867, 261]
# <Event, Hit Index> (60, 111575) matched to TPs [1004, 171]
# <Event, Hit Index> (95, 172959) matched to TPs [469, 468]
# <Event, Hit Index> (55, 99913) matched to TPs [309, 210]
# <Event, Hit Index> (4, 10715) matched to TPs [637, 636]
# <Event, Hit Index> (68, 127637) matched to TPs [114, 29]
# <Event, Hit Index> (82, 149939) matched to TPs [1010, 1009, 1008]
# <Event, Hit Index> (77, 140636) matched to TPs [625, 17]
# <Event, Hit Index> (41, 77292) matched to TPs [449, 25]
# <Event, Hit Index> (95, 173240) matched to TPs [150, 149]
# <Event, Hit Index> (54, 98581) matched to TPs [959, 38]
# <Event, Hit Index> (15, 31148) matched to TPs [193, 124]
# <Event, Hit Index> (3, 9069) matched to TPs [1020, 1008, 1007]
# <Event, Hit Index> (67, 126903) matched to TPs [120, 96]
# <Event, Hit Index> (14, 28088) matched to TPs [217, 17]
# <Event, Hit Index> (10, 22240) matched to TPs [694, 256]
# <Event, Hit Index> (23, 47437) matched to TPs [876, 533]
# <Event, Hit Index> (93, 169747) matched to TPs [490, 489]
# <Event, Hit Index> (50, 91191) matched to TPs [945, 297]
# <Event, Hit Index> (65, 121736) matched to TPs [234, 225]
# <Event, Hit Index> (42, 78917) matched to TPs [539, 249]
# <Event, Hit Index> (55, 100717) matched to TPs [671, 670]
# <Event, Hit Index> (58, 107910) matched to TPs [490, 489]
# <Event, Hit Index> (34, 65372) matched to TPs [107, 104]
# <Event, Hit Index> (18, 36687) matched to TPs [569, 73]
# <Event, Hit Index> (73, 134893) matched to TPs [688, 687]
# <Event, Hit Index> (10, 22991) matched to TPs [160, 111]
# <Event, Hit Index> (34, 64643) matched to TPs [686, 55]
# <Event, Hit Index> (66, 124443) matched to TPs [1108, 76]
# <Event, Hit Index> (23, 47885) matched to TPs [742, 741]
# <Event, Hit Index> (86, 158585) matched to TPs [604, 197]
# <Event, Hit Index> (39, 72912) matched to TPs [162, 131]
# <Event, Hit Index> (21, 41523) matched to TPs [170, 143]
# <Event, Hit Index> (56, 104142) matched to TPs [587, 586]
# <Event, Hit Index> (50, 91438) matched to TPs [780, 54]
# <Event, Hit Index> (62, 115395) matched to TPs [363, 345]
# <Event, Hit Index> (76, 139374) matched to TPs [127, 96]
# <Event, Hit Index> (67, 127052) matched to TPs [510, 224]
# <Event, Hit Index> (74, 137268) matched to TPs [158, 157]
# <Event, Hit Index> (87, 159546) matched to TPs [333, 8]
# <Event, Hit Index> (29, 57883) matched to TPs [597, 347, 97]
# <Event, Hit Index> (28, 56683) matched to TPs [164, 151]
# <Event, Hit Index> (34, 65112) matched to TPs [608, 238]
# <Event, Hit Index> (7, 17018) matched to TPs [179, 29]
# <Event, Hit Index> (31, 60532) matched to TPs [559, 558]
# <Event, Hit Index> (9, 21194) matched to TPs [438, 437]
# <Event, Hit Index> (57, 104727) matched to TPs [292, 100]
# <Event, Hit Index> (20, 39993) matched to TPs [98, 64]
# <Event, Hit Index> (52, 95049) matched to TPs [339, 111]
# <Event, Hit Index> (50, 90705) matched to TPs [117, 48]
# <Event, Hit Index> (92, 168682) matched to TPs [479, 474]
# <Event, Hit Index> (64, 119281) matched to TPs [244, 2]
# <Event, Hit Index> (67, 127241) matched to TPs [431, 324]
# <Event, Hit Index> (73, 135875) matched to TPs [338, 196]
# <Event, Hit Index> (46, 84720) matched to TPs [148, 75]
# <Event, Hit Index> (11, 23978) matched to TPs [369, 184]
# <Event, Hit Index> (85, 155671) matched to TPs [230, 137]
# <Event, Hit Index> (19, 38646) matched to TPs [559, 481]
# <Event, Hit Index> (14, 28647) matched to TPs [457, 23]
# <Event, Hit Index> (98, 178571) matched to TPs [645, 33]
# <Event, Hit Index> (41, 75979) matched to TPs [198, 157]
# <Event, Hit Index> (79, 143512) matched to TPs [862, 214]
# <Event, Hit Index> (5, 12199) matched to TPs [747, 712]
# <Event, Hit Index> (96, 174458) matched to TPs [390, 240]
# <Event, Hit Index> (88, 162313) matched to TPs [465, 464]
# <Event, Hit Index> (66, 125544) matched to TPs [409, 277]
# <Event, Hit Index> (97, 177265) matched to TPs [339, 200]
# <Event, Hit Index> (56, 103006) matched to TPs [654, 652]
# <Event, Hit Index> (57, 105062) matched to TPs [368, 33]
# <Event, Hit Index> (63, 118097) matched to TPs [239, 231]
# <Event, Hit Index> (26, 53786) matched to TPs [175, 111]
# <Event, Hit Index> (98, 179371) matched to TPs [484, 421]
# <Event, Hit Index> (73, 136387) matched to TPs [186, 185]
# <Event, Hit Index> (57, 106068) matched to TPs [267, 237]
# <Event, Hit Index> (66, 123751) matched to TPs [304, 157]
# <Event, Hit Index> (73, 136391) matched to TPs [641, 637]
# <Event, Hit Index> (84, 153254) matched to TPs [813, 560]
# <Event, Hit Index> (10, 22160) matched to TPs [111, 26]
# <Event, Hit Index> (30, 60055) matched to TPs [113, 4]
# <Event, Hit Index> (1, 3530) matched to TPs [303, 15]
# <Event, Hit Index> (28, 55876) matched to TPs [64, 61]
# <Event, Hit Index> (65, 121347) matched to TPs [689, 688]
# <Event, Hit Index> (8, 20364) matched to TPs [1063, 615]
# <Event, Hit Index> (77, 140982) matched to TPs [166, 76]
# <Event, Hit Index> (45, 82723) matched to TPs [653, 652]
# <Event, Hit Index> (6, 15629) matched to TPs [435, 431]
# <Event, Hit Index> (95, 172759) matched to TPs [152, 146]
# <Event, Hit Index> (42, 77948) matched to TPs [1143, 59]
# <Event, Hit Index> (3, 9146) matched to TPs [272, 14]
# <Event, Hit Index> (32, 62668) matched to TPs [199, 198]
# <Event, Hit Index> (23, 46259) matched to TPs [1015, 24]
# <Event, Hit Index> (49, 89459) matched to TPs [203, 199]
# <Event, Hit Index> (11, 23670) matched to TPs [89, 56]
# <Event, Hit Index> (66, 126001) matched to TPs [866, 519]
# <Event, Hit Index> (33, 64128) matched to TPs [332, 45]
# <Event, Hit Index> (90, 165825) matched to TPs [650, 649]
# <Event, Hit Index> (0, 1323) matched to TPs [658, 305]
# <Event, Hit Index> (47, 86216) matched to TPs [631, 630]
# <Event, Hit Index> (90, 164954) matched to TPs [371, 77]
# <Event, Hit Index> (0, 354) matched to TPs [668, 223]
# <Event, Hit Index> (84, 153550) matched to TPs [491, 280]
# <Event, Hit Index> (2, 5863) matched to TPs [844, 670]
# <Event, Hit Index> (27, 54802) matched to TPs [977, 27]
# <Event, Hit Index> (95, 172684) matched to TPs [546, 0]
# <Event, Hit Index> (66, 124768) matched to TPs [1188, 990]

# %%
concat_stereo_tp_idx_
# Out:
# {(66, 125968): [196],
#  (23, 47102): [71],
#  (94, 170415): [885],
#  (26, 52833): [90],
#  (97, 176058): [355],
#  (65, 121456): [233],
#  (87, 159816): [804],
#  (68, 128014): [576],
#  (91, 167494): [],
#  (66, 124919): [154],
#  (23, 47491): [105],
#  (97, 177223): [125],
#  (0, 862): [1032],
#  (84, 153199): [],
#  (98, 178314): [54],
#  (84, 154295): [458],
#  (2, 6003): [796],
#  (66, 123538): [653],
#  (23, 46204): [1067],
#  (94, 170793): [224],
#  (26, 53219): [484],
#  (62, 115893): [13],
#  (0, 1649): [572],
#  (84, 154954): [],
#  (87, 161486): [],
#  (68, 128396): [345],
#  (91, 167108): [40],
#  (73, 135025): [136],
#  (66, 124025): [],
#  (0, 476): [959],
#  ...}

# %%
matched_stereo_rechit_ = data_.array('stereoHitMatch')

# %%
a = {}
a.update?

# %%
{}.update

# %%
# Iterate over all events and track indices to find a match for rechits

# Generate a map of rechit to indices of the tracks it matches
rechit_to_track_map_ = {}
global_counter_ = 0

# For each event
for event_ in range(len(stereo_tp_idx_)):
    
    # Create a new list for all TP indices from tracks
    event_tp_list_ = []
    
    total_hits_ = len(stereo_tp_idx_[event_])
    
    # Tracks that correspond to a TP
    tp_matched_tracks_ = 0
    # Tracks that have rechits matched to them
    rechit_matched_tracks_ = 0
    # Total tracks in the event
    total_tracks_ = len(track_tp_idx[event_])
    
    '''
    Need to do this for tracks not rechits
    
    # Add all the TP indices (including repetitions) 
    # for rechits in a single array
    for stereo_tp_list_ in stereo_tp_idx_[event_]:
        if len(stereo_tp_list_) > 0:
            event_tp_list_.extend(stereo_tp_list_)
            matched_hits_ += 1
    '''
    
    # Generate a list of all track TPs in the event
    for track_tp_list_ in track_tp_idx_[event_]:
        if len(track_tp_list_) > 0:
            event_tp_list_.extend(track_tp_list_)
            tp_matched_tracks_ += 1
            
    
    # Print the number of matched/total tracks to TPs in the event
    print tp_matched_tracks_, "/", total_tracks_, "tracks matched to", len(list(set(event_tp_list_))), "tracking particles"
    # TODO: Print rechits matched/total rechits
    
    # List all the tracks and TP lists for each track
    enum_track_tp_idx_ = enumerate(track_tp_idx_[event_])

    # For every index list in the stereo TP array
    for idx_list_ in stereo_tp_idx_[event_]:
        for idx_ in idx_list_:
            # Match is an array of track indices that matched the search idx
            match_ = [track_num_ for track_num_, tp_list_ in enum_track_tp_idx_ if idx_ in tp_list_]
            
            if match_:
                for track_num_ in match_:
                    if (event_, idx_) in rechit_to_track_map_:
                        rechit_to_track_map_[(event_, idx_)].append([global_counter_])
                        global_counter_ += 1
                    else:
                        rechit_to_track_map_[(event_, idx_)] = [[global_counter_]]
                        global_counter_ += 1
                    
 
                
    # Count the rechits with hit match value = 1
    # Use this to corroborate that you're counting the right hits
    
    #hit_match_total_ = 
    #for hit_match_value_ in matched_stereo_rechit_:
        #if hit_match_value_ > 0:
# Out:
#   File "<ipython-input-20-a1a57360b4b3>", line 62
#
#     ^
# IndentationError: expected an indented block

# %%
# associate a global track index for each rechit

# unique_id_ is a tuple of event number and track index for that event
# (event_num_, track_idx_)
# But what if track index has multiple TPs???

# track_event_map_ associates a global unique index to each unique_id_
# <global_unique_idx_> : <unique_id_>

# rechit_track_map_ is a list of rechits associated with each global unique index
# <global_unique_idx_> : [<rechitdata>...]

# This code block ignores the 'matchedHit' (0 or 1) column 
# because the current data does not have the correct length
track_index_ = 0
hitmatch_ = 0
rechit_track_map_ = {}
track_event_map_ = {}
nomatch_ = 0
total_rechits_ = 0

for event_ in range(len(stereo_tp_idx_)):
    
    # Check if for that event that hit has a value of matched = 1
    for hitIndex_ in range(len(matched_stereo_rechit_[event_])):
        total_rechits_+=1
        if stereo_tp_idx_[event_][hitIndex_] != -1 and stereo_tp_idx_[event_][hitIndex_] in track_tp_idx_[event_]: 
            hitmatch_+=1
                          
            # This means that hit has been matched to a track
            # Now associate a unique ID to that track index and
            # add that row into the rechit map
            unique_id_ = (event_, stereo_tp_idx_[event_][hitIndex_])
            
            # Store the rechit properties on a per-track basis in a map
            # corresponding to one single track ID per list of rechit properties
            if unique_id_ in track_event_map_:
                # This means there is already a list at that value
                # You can add r, phi, eta, and whatever we need to store
                rechit_track_map_[track_event_map_[unique_id_]].append(
                    [stereo_x_[event_][hitIndex_], stereo_y_[event_][hitIndex_], stereo_z_[event_][hitIndex_]])
            else:
                # This means we need to create a list at that value
                track_event_map_[unique_id_] = track_index_
                track_index_ += 1
                # You can add r, phi, eta, and whatever we need to store
                rechit_track_map_[track_event_map_[unique_id_]] = []
                rechit_track_map_[track_event_map_[unique_id_]].append(
                    [stereo_x_[event_][hitIndex_], stereo_y_[event_][hitIndex_], stereo_z_[event_][hitIndex_]])
        else:
            nomatch_+=1

# %% [markdown]
# '''
#
#
#
#     # The above statement returns an array with count of 0's and 1's
#     # we need only the 1's
#     if len(hit_match_count_) == 2:
#         print hit_match_total_[1], "/",  len(stereo_tp_idx_[i]), "hits matched to",
#         print unique_tracks_matched_per_event_,"/", len(track_tp_idx_[i]),"tracks"
#         print "No Match for", stereo_tp_idx_[i].tolist().count(-1), "hits and", track_tp_idx_[i].tolist().count(-2), "tracks"
#         matched_hits_ += hit_match_count_[1]
#     else:
#         print "No hits matched for event-----------------------", j
#         no_matched_tracks_.append([i, hit_match_total_[0], len(stereo_tp_idx_[i]), unique_tracks_matched_per_event_, len(track_tp_idx_[i])])
#     matched_tracks_ += unique_tracks_matched_per_event_
#
#
# total_hits_ = sum([len(hits) for hits in stereo_tp_idx_])
# total_tracks_ = sum([len(tracks) for tracks in track_tp_idx_])
# # Summary
# print "\n", matched_hits_, "/", total_hits_, "hits matched to", matched_tracks_, "/", total_tracks_, "tracks\n"
#
# for unmatched_event_ in no_matched_tracks_:
#     print unmatched_event_[1], "hits with zero TP of total",  unmatched_event_[2], "hits and",
#     print unmatched_event_[3],"/", unmatched_event_[4],"matched tracks"
#
# unmatched_event_numbers_ = []
# for event_data_ in no_matched_tracks_:
#     print "\nEvent", event_data_[0]
#     unmatched_event_numbers_.append(event_data_[0])
#     print "TP = 0:", stereo_tp_idx_[event_data_[0]].tolist().count(0), "hits and", track_tp_idx_[event_data_[0]].tolist().count(0), "tracks"
#     print "No Rechit TP Match for", stereo_tp_idx_[event_data_[0]].tolist().count(-1), "/", event_data_[2], "hits"
#     print "No Track TP Match:", track_tp_idx_[event_data_[0]].tolist().count(-2), "/", event_data_[4], "tracks"
#     #print "Total Particles:", len(stereo_tp_idx_[event_data_[0]])
#
#     for i in track_tp_idx_[event_data_[0]]:
#         for j in range(len(stereo_tp_idx_[i]:
#             if
#             print "ERROR: Match found ---------------------------", i
# '''

# %%
# Print the modified track parameter plots with all the matched and unmatched events
for i, key in zip(range(5), ["trackEta", "trackPhi", "qoverp", "dxy", "dsz"]):
    track_param_ = data_.array(key)
    unmatched_data_ = []
    concat_track_param_ = []
    print "Iterating over", key
    
    for j in range(len(track_param_)):
        if j in unmatched_event_numbers_:
            # Use the event number from the stored data for the event with no matched tracks
            unmatched_data_.extend(track_param_[j])
        else:
            concat_track_param_.extend(track_param_[j])
    
    print "Number of elements:", len(concat_track_param_)
    ax_ = plt.subplot()        
        
    # Plot that single element on the histogram in a different color
    plt.hist(unmatched_data_, histtype='bar', bins=20, align='mid', orientation='vertical', color='red', alpha=0.5, label='unmatched')

    #plt.hist([unmatched_data_, concat_track_param_], histtype='bar', bins=20, align='mid', orientation='vertical', alpha=0.5, label=['unmatched', 'matched'])
    plt.hist(concat_track_param_, histtype='bar', bins=20, align='mid', orientation='vertical', alpha=0.5, label='matched')
    
    plt.legend(loc='upper right')
    plt.ylabel('Frequency')
    plt.yscale('log')
    plt.xlabel('Distribution of ' + key)
    plt.title(key + ' Distribution')
    # plt.savefig('plots/' + gen_event_ + '/track/' + key)
    plt.show()

# %%
track_eta_ = data_.array('trackEta')

for i, key in zip(range(5), ["trackEta", "trackPhi", "qoverp", "dxy", "dsz"]):
    track_param_ = data_.array(key)
    print "Iterating over", key

    
    discarded_track_param_ = []
    concat_track_param_ = []
    unmatched_track_param_ = []

    for j in range(len(track_param_)):
        for k in range(len(track_param_[j])):
            
            # Constrain the track eta value
            if track_eta_[j][k] < 0.9 and track_eta_[j][k] > (-0.9):
                if j in unmatched_event_numbers_:
                    unmatched_track_param_.append(track_param_[j][k])
                else:
                    concat_track_param_.append(track_param_[j][k])
            else:
                discarded_track_param_.append(track_param_[j][k])
    
    print "Discarded", len(discarded_track_param_), "and matched", len(concat_track_param_), "/", 
    print len(concat_track_param_)+len(unmatched_track_param_), "tracks"
    ax_ = plt.subplot()
    
    # Plot that single element on the histogram in a different color
    plt.hist(unmatched_track_param_, histtype='bar', bins=40, align='mid', orientation='vertical', color='red', alpha=0.5, label='unmatched')

    #plt.hist([unmatched_data_, concat_track_param_], histtype='bar', bins=20, align='mid', orientation='vertical', alpha=0.5, label=['unmatched', 'matched'])
    plt.hist(concat_track_param_, histtype='bar', bins=40, align='mid', orientation='vertical', alpha=0.5, label='matched')
    plt.hist(discarded_track_param_, histtype='bar', bins=40, align='mid', orientation='vertical', alpha=0.2, color='green', label='discarded')
    plt.legend(loc='upper right')
    plt.ylabel('Frequency')
    plt.yscale('log')
    plt.xlabel('Distribution of ' + key)
    plt.title(key + ' Distribution')
    plt.savefig('plots/' + gen_event_ + '/track/etabound-' + key)
    plt.show()

# %%
track_pt_ = data_.array('trackPt').tolist()
track_eta_ = data_.array('trackEta').tolist()
concat_track_pt_ = []
unmatched_track_pt_ = []
discarded_track_pt_= []

discarded_index_map_ = []

for j in range(len(track_pt_)):
    for k in range(len(track_pt_[j])):
       
        # Constrain the track eta value
        if track_eta_[j][k] < 0.9 and track_eta_[j][k] > (-0.9):
            if j in unmatched_event_numbers_:
                unmatched_track_pt_.append(track_pt_[j][k])
            else:
                concat_track_pt_.append(track_pt_[j][k])
        else:
            discarded_track_pt_.append(track_pt_[j][k])


print "Discarded", len(discarded_track_pt_), "and matched", len(concat_track_pt_), "/", len(concat_track_pt_) + len(unmatched_track_pt_), "tracks"

# %%
np.log10?

# %%
binning_ = np.logspace(np.log10(0.01), np.log10(10000), 100)
plt.hist(concat_track_pt_, histtype='bar', bins=binning_, align='mid', orientation='vertical', alpha=0.6, label='matched')
plt.hist(unmatched_track_pt_, histtype='bar', bins=binning_, align='mid', orientation='vertical', alpha=0.8, label='unmatched')
plt.hist(discarded_track_pt_, histtype='bar', bins=binning_, align='mid', orientation='vertical', alpha=0.4, label='discarded')
plt.legend(loc='upper right')
plt.ylabel('Frequency')
plt.xlabel('Distribution of pt')
plt.xscale('log')
plt.yscale('log')
plt.title('Track pt Distribution')
plt.savefig('plots/' + gen_event_ + '/track/etabound-trackpt-logscale')
plt.show()

# %%
# Check that the arrays are of equal lengths - i.e. each point has an index and an x, y, z coordinate
for i in range(len(stereo_tp_idx_)):
    #print len(stereo_tp_idx_[i]), len(stereo_x_[i])
    if len(stereo_tp_idx_[i]) != len(stereo_x_[i]) or len(stereo_tp_idx_[i]) != len(stereo_y_[i]) or len(stereo_tp_idx_[i]) != len(stereo_z_[i]):
        print "Length of indices and points does not match"
        if len(stereo_tp_idx_[i]) > len(stereo_x_[i]):
            print "There are", len(stereo_tp_idx_[i]) - len(stereo_x_[i]), "less hits than clusters"
        else:
            print "There are no cluster indices (even -1) for", len(stereo_x_[i]) - len(stereo_tp_idx_[i]), "hits"

# %%
total_tracks_ = sum([len(track) for track in track_tp_idx_])
print "Total tracks: ", total_tracks_

# %% [markdown]
# # associate a global track index for each rechit
# '''
# track_index_ = 0
# x_counter_ = 0
# rechit_track_map_ = {}
# track_event_map_ = {}
#
# for event in range(len(stereo_tp_idx_)):
#
#     # Check if for that event that hit has a value of matched = 1
#     for hitIndex in range(len(matched_stereo_rechit_[event])):
#
#         if matched_stereo_rechit_[event][hitIndex] == 1:
#             if stereo_tp_idx_[event][hitIndex] == -1:
#                 x_counter_+=1
#
#             else:
#
#                 # This means that hit has been matched to a track
#                 # Now associate a unique ID to that track index and
#                 # add that row into the rechit map
#                 unique_id_ = (event, stereo_tp_idx_[event][hitIndex])
#
#             # Store the rechit properties on a per-track basis in a map
#             # corresponding to one single track ID per list of rechit properties
#             if unique_id_ in track_event_map_:
#                 # This means there is already a list at that value
#                 # You can add r, phi, eta, and whatever we need to store
#                 rechit_track_map_[track_event_map_[unique_id_]].append(
#                     [stereo_x_[event][hitIndex], stereo_y_[event][hitIndex], stereo_z_[event][hitIndex]])
#             else:
#                 # This means we need to create a list at that value
#                 track_event_map_[unique_id_] = track_index_
#                 track_index_ += 1
#                 # You can add r, phi, eta, and whatever we need to store
#                 rechit_track_map_[track_event_map_[unique_id_]] = []
#                 rechit_track_map_[track_event_map_[unique_id_]].append(
#                     [stereo_x_[event][hitIndex], stereo_y_[event][hitIndex], stereo_z_[event][hitIndex]])
# '''

# %%
# associate a global track index for each rechit

# unique_id_ is a tuple of event number and track index for that event
# track_event_map_ associates a global unique index to each unique_id_
# rechit_track_map_ is a list of rechits associated with each global unique index

# This code block ignores the 'matchedHit' (0 or 1) column 
# because the current data does not have the correct length
track_index_ = 0
hitmatch_ = 0
rechit_track_map_ = {}
track_event_map_ = {}
nomatch_ = 0
total_rechits_ = 0

for event_ in range(len(stereo_tp_idx_)):
    
    # Check if for that event that hit has a value of matched = 1
    for hitIndex_ in range(len(matched_stereo_rechit_[event_])):
        total_rechits_+=1
        if stereo_tp_idx_[event_][hitIndex_] != -1 and stereo_tp_idx_[event_][hitIndex_] in track_tp_idx_[event_]: 
            hitmatch_+=1
                          
            # This means that hit has been matched to a track
            # Now associate a unique ID to that track index and
            # add that row into the rechit map
            unique_id_ = (event_, stereo_tp_idx_[event_][hitIndex_])
            
            # Store the rechit properties on a per-track basis in a map
            # corresponding to one single track ID per list of rechit properties
            if unique_id_ in track_event_map_:
                # This means there is already a list at that value
                # You can add r, phi, eta, and whatever we need to store
                rechit_track_map_[track_event_map_[unique_id_]].append(
                    [stereo_x_[event_][hitIndex_], stereo_y_[event_][hitIndex_], stereo_z_[event_][hitIndex_]])
            else:
                # This means we need to create a list at that value
                track_event_map_[unique_id_] = track_index_
                track_index_ += 1
                # You can add r, phi, eta, and whatever we need to store
                rechit_track_map_[track_event_map_[unique_id_]] = []
                rechit_track_map_[track_event_map_[unique_id_]].append(
                    [stereo_x_[event_][hitIndex_], stereo_y_[event_][hitIndex_], stereo_z_[event_][hitIndex_]])
        else:
            nomatch_+=1

# %%
print "Tracks matched for", hitmatch_, "of", total_rechits_, "rechits"

# %%
# This is a test to be used in case we utilise a matchedHit column in our code
x_counter_=0
matched_stereo_rechit_ = data_.array('stereoHitMatch')
for event_number_ in range(len(stereo_tp_idx_)):
    if len(matched_stereo_rechit_[event_number_]) != len(stereo_tp_idx_[event_number_]):
        print "The number of matched+unmatched and total hits does not tally"
        print "This is an issue for C++!"
        break

# %%
for event_ in range(len(matched_stereo_rechit_)):
    for match_ in range(len(matched_stereo_rechit_[event_])):
        if stereo_tp_idx_[event_][match_]==1:
            if stereo_tp_idx_[event_][match_]==-1:
                print "Problem at", event_, match_
                break
            else:
                continue

# %%
#for key in sorted(track_event_map_):
#    print key, track_event_map_[key]    
#print sorted(track_event_map_.values())

# %%
track_count_ = {}
for track in rechit_track_map_.keys():
    count_ = len(rechit_track_map_[track])
    if count_ in track_count_:
        track_count_[count_] += 1
    else:
        track_count_[count_] = 1

# %%
track_count_

# %%
plt.clf()
ax_ = plt.subplot()
# Plot the Histogram for Tracks vs. Rechits
ax_.set_title('Hits vs. Tracks')
ax_.hist(track_count_.keys(), weights=track_count_.values(), bins=22)
plt.ylabel('Number of Tracks')
plt.yscale('log')
plt.xlabel('Number of Hits')
plt.savefig('plots/' + gen_event_ + '/track/hitdistribution')
plt.show()
