# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import uproot
import pandas as pd

# %%
gen_event_ = "ttbar-500"
outfile_ = "outfile-" + gen_event_ + ".root"
data_ = uproot.open(outfile_)["ntuples"]["tree"]
data_.keys()
# Out:
# ['nevent',
#  'nlumi',
#  'nrun',
#  'trackEta',
#  'trackPhi',
#  'qoverp',
#  'dxy',
#  'dsz',
#  'trackPt',
#  'trackTPIdx',
#  'trackEtaError',
#  'trackPhiError',
#  'qoverpError',
#  'dxyError',
#  'dszError',
#  'trackPtError',
#  'trackParameters',
#  'covarianceArray',
#  'stereoHitX',
#  'stereoHitY',
#  'stereoHitZ',
#  'stereoHitR',
#  'stereoHitPhi',
#  'stereoHitEta',
#  'stereoHitLayer',
#  'stereoTPIndex',
#  'stereoHitMatch',
#  'monoHitX',
#  'monoHitY',
#  'monoHitZ',
#  'monoHitR',
#  'monoHitPhi',
#  'monoHitEta',
#  'monoHitLayer',
#  'monoTPIndex',
#  'monoHitMatch']

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig_ = plt.figure()
ax_ = Axes3D(fig_)

# %%
# Find Number of Events based on any property length
track_eta_ = data_.array("trackEta")
print "Number of Events: ", len(track_eta_)
# Out:
# Number of Events:  500

# %%
'''
track_properties_ = []
for key in data_.keys():
    if key == 'trackParameters' or key == 'covarianceArray' or 'Hit' in key or 'n' in key or 'Error' in key:
        continue
    else:
        track_properties_.append(key)
'''

for i, key in zip(range(5), ["trackEta", "trackPhi", "qoverp", "dxy", "dsz"]):
    track_param_ = data_.array(key)

    print "Iterating over", key
    concat_track_param_ = []
    for j in range(len(track_param_)):
        concat_track_param_.extend(track_param_[j])
    plt.clf()
    ax_ = plt.subplot()
    ax_.hist(concat_track_param_, histtype='bar', bins=20, align='mid', orientation='vertical')
    plt.ylabel('Events')
    plt.xlabel('Distribution of ' + key)
    plt.title(key + ' Distribution')
    plt.savefig('plots/' + gen_event_ + '/track/' + key)
    plt.show()
# Out:
# Iterating over trackEta
# Iterating over trackPhi
# Iterating over qoverp
# Iterating over dxy
# Iterating over dsz

# %%
plt.clf()

# %%
# Plot the distribution of tracks over events 
# using the length of any paramater array - e.g. track eta

track_Eta_ = data_.array("trackEta")
concat_num_tracks_ = []

for i in range(len(track_Eta_)):
     concat_num_tracks_.append(len(track_Eta_[i]))

ax_ = plt.subplot()
ax_.hist(concat_num_tracks_, histtype='bar', range=(10, 90), bins=80, align='mid', orientation='vertical')

plt.xlabel('No. of Tracks')
plt.ylabel('No. of Events')
plt.title('Tracks vs. Events Distribution')
plt.grid(True)
plt.savefig('plots/' + gen_event_ + '/track/event-track-distribution')
plt.show()

# %%
# This plot is just reflecting how root plots the distribution of Rechits along a single axis (X)
mono_x_ = data_.array('monoHitX')
plt.clf()
ax_ = plt.subplot()

mono_rechit_length_ = []

# assumes length of mono_x_ mono_y_ and mono_z_ is the same
for i in range(len(mono_x_)):
        mono_rechit_length_.extend(mono_x_[i])
        
print len(mono_rechit_length_)

ax_.hist(mono_rechit_length_, bins=100, histtype='stepfilled', align='mid', orientation='vertical', color='r', density=True)
plt.show()
# Out:
# 2041151

# %%
# ToDo: Add lognorm colormap

mono_x_ = data_.array("monoHitX") 
mono_y_ = data_.array("monoHitY")
mono_z_ = data_.array("monoHitZ")

 

if len(mono_x_) == len(mono_y_):
    concat_mono_x_ = []
    concat_mono_y_ = []

    for i in range(len(mono_x_)):
        concat_mono_x_.extend(mono_x_[i])
        concat_mono_y_.extend(mono_y_[i])

plt.clf()
ax_ = plt.subplot()
# Plot the 2D Histogram for Mono Rechits
ax_.set_title('MonoRechit Distribution')
ax_.hist2d(concat_mono_x_, concat_mono_y_, bins=100, normed=True, cmap='hot')
plt.savefig('plots/' + gen_event_ + '/stereo/rechitdistribution')
plt.show()

# %%
# ToDo: Add lognorm colormap

stereo_x_ = data_.array("stereoHitX") 
stereo_y_ = data_.array("stereoHitY")
stereo_z_ = data_.array("stereoHitZ")

 

if len(mono_x_) == len(mono_y_):
    concat_stereo_x_ = []
    concat_stereo_y_ = []

    for i in range(len(mono_x_)):
        concat_stereo_x_.extend(stereo_x_[i])
        concat_stereo_y_.extend(stereo_y_[i])

plt.clf()
ax_ = plt.subplot()
# Plot the 2D Histogram for Mono Rechits
ax_.set_title('Stereo Distribution')
ax_.hist2d(concat_stereo_x_, concat_stereo_y_, bins=100, normed=True, cmap='hot')
plt.savefig('plots/' + gen_event_ + '/stereo/rechitdistribution')
plt.show()

# %%
# Define a loop that plots R, Phi, and Eta for Mono Hits

for param in ["monoHitR", "monoHitPhi", "monoHitEta"]:
    mono_param_ = data_.array(param)
    concat_mono_param_ = []
    
    for i in range(len(mono_param_)):
            concat_mono_param_.extend(mono_param_[i])

    plt.clf()
    ax_ = plt.subplot()
    # Plot the 2D Histogram for Mono Rechits
    ax_.set_title('MonoRechit Distribution of ' + param)
    ax_.hist(concat_mono_param_, bins=20, histtype='stepfilled', align='mid', orientation='vertical', density=True)
    plt.xlabel('Value of ' + param)
    plt.ylabel('Distribution of ' + param)
    plt.title(param + ' Distribution')
    plt.savefig('plots/' + gen_event_ + '/mono/' + param)
    plt.show()

# %%
# Define a loop that plots R, Phi, and Eta for Stereo Hits

for param in ["stereoHitR", "stereoHitPhi", "stereoHitEta"]:
    mono_param_ = data_.array(param)
    concat_mono_param_ = []
    
    for i in range(len(mono_param_)):
            concat_mono_param_.extend(mono_param_[i])

    plt.clf()
    ax_ = plt.subplot()
    # Plot the 2D Histogram for Mono Rechits
    ax_.set_title('MonoRechit Distribution of ' + param)
    ax_.hist(concat_mono_param_, bins=20, histtype='stepfilled', align='mid', orientation='vertical', density=True)
    plt.xlabel('Value of ' + param)
    plt.ylabel('Distribution of ' + param)
    plt.title(param + ' Distribution')
    plt.savefig('plots/' + gen_event_ + '/mono/' + param)
    plt.show()

# %%
stereo_tp_idx_ = data_.array('stereoTPIndex')
track_tp_idx_ = data_.array('trackTPIdx')

# %%
tmp_ = []
for j in range(len(stereo_tp_idx_)):
    tmp_.append(stereo_tp_idx_[j].tolist().count(-1))

print len(track_tp_idx_) == len(stereo_tp_idx_)
# Out:
# True

# %%
matched_hits_ = 0
matched_stereo_rechit_ = data_.array('stereoHitMatch')
matched_tracks_ = 0
no_matched_tracks_ = []
# This should not be required with the availability of "matched hit" 
# Iterate over all events and track indices to find a match for rechits
for j in range(len(stereo_tp_idx_)):
    # Print the number of points in each event
    # print len(stereo_tp_idx_[j]), "hits from", len(set(stereo_tp_idx_[j])), "tracking particles"
    unique_tracks_matched_per_event_ = 0
    
    for i in list(set(stereo_tp_idx_[j])):
        if i in track_tp_idx_[j]:
            unique_tracks_matched_per_event_+=1
    
    # Count the entries with hit match value = 1
    # Use this to corroborate that you're counting the right hits
    hit_match_count_ = np.bincount(matched_stereo_rechit_[j])
    
    # The above statement returns an array with count of 0's and 1's
    # we need only the 1's
    if len(hit_match_count_) == 2:
        print hit_match_count_[1], "/",  len(stereo_tp_idx_[j]), "hits matched to",
        print unique_tracks_matched_per_event_,"/", len(track_tp_idx_[j]),"tracks"
        print "No Match for", stereo_tp_idx_[j].tolist().count(-1), "hits and", track_tp_idx_[j].tolist().count(-2), "tracks"
        matched_hits_ += hit_match_count_[1]
    else:
        print "No hits matched for event-----------------------", j
        no_matched_tracks_.append([j, hit_match_count_[0], len(stereo_tp_idx_[j]), unique_tracks_matched_per_event_, len(track_tp_idx_[j])])
    matched_tracks_ += unique_tracks_matched_per_event_
    

total_hits_ = sum([len(hits) for hits in stereo_tp_idx_])
total_tracks_ = sum([len(tracks) for tracks in track_tp_idx_])
# Summary
print "\n", matched_hits_, "/", total_hits_, "hits matched to", matched_tracks_, "/", total_tracks_, "tracks\n"

for unmatched_event_ in no_matched_tracks_:
    print unmatched_event_[1], "hits with zero TP of total",  unmatched_event_[2], "hits and",
    print unmatched_event_[3],"/", unmatched_event_[4],"matched tracks"

unmatched_event_numbers_ = []
for event_data_ in no_matched_tracks_:
    print "\nEvent", event_data_[0]
    unmatched_event_numbers_.append(event_data_[0])
    print "TP = 0:", stereo_tp_idx_[event_data_[0]].tolist().count(0), "hits and", track_tp_idx_[event_data_[0]].tolist().count(0), "tracks"
    print "No Rechit TP Match for", stereo_tp_idx_[event_data_[0]].tolist().count(-1), "/", event_data_[2], "hits"
    print "No Track TP Match:", track_tp_idx_[event_data_[0]].tolist().count(-2), "/", event_data_[4], "tracks"
    #print "Total Particles:", len(stereo_tp_idx_[event_data_[0]])

    for i in track_tp_idx_[event_data_[0]]:
        if i in stereo_tp_idx_[event_data_[0]]:
            print "ERROR: Match found ---------------------------", i
# Out:
# 179 / 2142 hits matched to 29 / 37 tracks
# No Match for 584 hits and 5 tracks
# 162 / 2071 hits matched to 34 / 42 tracks
# No Match for 653 hits and 3 tracks
# 254 / 2054 hits matched to 57 / 64 tracks
# No Match for 506 hits and 5 tracks
# 363 / 3375 hits matched to 73 / 90 tracks
# No Match for 780 hits and 11 tracks
# 198 / 1877 hits matched to 45 / 49 tracks
# No Match for 430 hits and 2 tracks
# 316 / 2766 hits matched to 60 / 65 tracks
# No Match for 639 hits and 3 tracks
# 195 / 2151 hits matched to 35 / 35 tracks
# No Match for 641 hits and 0 tracks
# 163 / 1835 hits matched to 32 / 42 tracks
# No Match for 432 hits and 6 tracks
# 219 / 2165 hits matched to 48 / 75 tracks
# No Match for 522 hits and 17 tracks
# 141 / 1327 hits matched to 31 / 38 tracks
# No Match for 307 hits and 2 tracks
# No hits matched for event----------------------- 10
# 223 / 1951 hits matched to 44 / 55 tracks
# No Match for 556 hits and 4 tracks
# 172 / 1404 hits matched to 38 / 40 tracks
# No Match for 385 hits and 1 tracks
# 116 / 1152 hits matched to 22 / 23 tracks
# No Match for 260 hits and 0 tracks
# 218 / 2890 hits matched to 49 / 57 tracks
# No Match for 763 hits and 4 tracks
# 154 / 1753 hits matched to 32 / 35 tracks
# No Match for 442 hits and 2 tracks
# 201 / 1877 hits matched to 44 / 58 tracks
# No Match for 467 hits and 8 tracks
# 167 / 1447 hits matched to 31 / 36 tracks
# No Match for 343 hits and 2 tracks
# 135 / 1314 hits matched to 32 / 35 tracks
# No Match for 330 hits and 1 tracks
# 224 / 2346 hits matched to 48 / 55 tracks
# No Match for 620 hits and 4 tracks
# 191 / 1337 hits matched to 38 / 42 tracks
# No Match for 267 hits and 2 tracks
# 214 / 2174 hits matched to 47 / 55 tracks
# No Match for 534 hits and 4 tracks
# 261 / 2405 hits matched to 52 / 57 tracks
# No Match for 597 hits and 1 tracks
# 260 / 2541 hits matched to 54 / 63 tracks
# No Match for 711 hits and 6 tracks
# 169 / 2192 hits matched to 35 / 40 tracks
# No Match for 505 hits and 3 tracks
# 215 / 1997 hits matched to 46 / 49 tracks
# No Match for 376 hits and 0 tracks
# 163 / 1630 hits matched to 35 / 44 tracks
# No Match for 428 hits and 7 tracks
# 145 / 1957 hits matched to 30 / 35 tracks
# No Match for 513 hits and 5 tracks
# 226 / 1344 hits matched to 45 / 53 tracks
# No Match for 297 hits and 6 tracks
# 237 / 1497 hits matched to 59 / 67 tracks
# No Match for 330 hits and 7 tracks
# 211 / 1812 hits matched to 46 / 50 tracks
# No Match for 440 hits and 2 tracks
# 170 / 1493 hits matched to 39 / 45 tracks
# No Match for 386 hits and 2 tracks
# 148 / 1409 hits matched to 33 / 37 tracks
# No Match for 393 hits and 2 tracks
# 80 / 965 hits matched to 17 / 21 tracks
# No Match for 285 hits and 3 tracks
# 210 / 1625 hits matched to 47 / 56 tracks
# No Match for 429 hits and 5 tracks
# 219 / 1439 hits matched to 37 / 41 tracks
# No Match for 396 hits and 1 tracks
# 107 / 964 hits matched to 23 / 23 tracks
# No Match for 150 hits and 0 tracks
# 206 / 1928 hits matched to 41 / 47 tracks
# No Match for 533 hits and 1 tracks
# 167 / 1516 hits matched to 35 / 45 tracks
# No Match for 339 hits and 9 tracks
# 144 / 1820 hits matched to 32 / 39 tracks
# No Match for 506 hits and 3 tracks
# No hits matched for event----------------------- 40
# 93 / 1655 hits matched to 21 / 22 tracks
# No Match for 493 hits and 0 tracks
# 238 / 2659 hits matched to 49 / 63 tracks
# No Match for 610 hits and 4 tracks
# 63 / 665 hits matched to 9 / 9 tracks
# No Match for 177 hits and 0 tracks
# 134 / 1285 hits matched to 26 / 28 tracks
# No Match for 422 hits and 1 tracks
# 276 / 1999 hits matched to 52 / 60 tracks
# No Match for 500 hits and 4 tracks
# 143 / 649 hits matched to 28 / 33 tracks
# No Match for 114 hits and 3 tracks
# 163 / 2005 hits matched to 37 / 43 tracks
# No Match for 607 hits and 5 tracks
# 139 / 1780 hits matched to 29 / 32 tracks
# No Match for 460 hits and 0 tracks
# 192 / 1702 hits matched to 40 / 42 tracks
# No Match for 379 hits and 1 tracks
# 248 / 2173 hits matched to 55 / 61 tracks
# No Match for 540 hits and 4 tracks
# 127 / 1535 hits matched to 28 / 37 tracks
# No Match for 435 hits and 4 tracks
# 226 / 1812 hits matched to 46 / 50 tracks
# No Match for 541 hits and 1 tracks
# 175 / 1667 hits matched to 36 / 45 tracks
# No Match for 532 hits and 5 tracks
# 266 / 2144 hits matched to 46 / 51 tracks
# No Match for 538 hits and 2 tracks
# 437 / 3279 hits matched to 88 / 93 tracks
# No Match for 801 hits and 2 tracks
# 130 / 1540 hits matched to 28 / 33 tracks
# No Match for 343 hits and 5 tracks
# 391 / 3318 hits matched to 79 / 86 tracks
# No Match for 835 hits and 7 tracks
# 158 / 1642 hits matched to 29 / 36 tracks
# No Match for 390 hits and 3 tracks
# 210 / 1864 hits matched to 43 / 53 tracks
# No Match for 571 hits and 4 tracks
# 227 / 2527 hits matched to 51 / 59 tracks
# No Match for 640 hits and 4 tracks
# 111 / 1266 hits matched to 25 / 27 tracks
# No Match for 392 hits and 0 tracks
# 183 / 1165 hits matched to 31 / 36 tracks
# No Match for 318 hits and 0 tracks
# 210 / 2410 hits matched to 39 / 43 tracks
# No Match for 731 hits and 0 tracks
# 264 / 2531 hits matched to 55 / 61 tracks
# No Match for 658 hits and 5 tracks
# 319 / 2346 hits matched to 61 / 69 tracks
# No Match for 544 hits and 4 tracks
# 403 / 2836 hits matched to 74 / 82 tracks
# No Match for 658 hits and 5 tracks
# 176 / 1265 hits matched to 33 / 37 tracks
# No Match for 345 hits and 1 tracks
# 148 / 1362 hits matched to 30 / 33 tracks
# No Match for 285 hits and 2 tracks
# 141 / 886 hits matched to 26 / 30 tracks
# No Match for 248 hits and 2 tracks
# 167 / 1598 hits matched to 36 / 40 tracks
# No Match for 428 hits and 3 tracks
# 156 / 997 hits matched to 30 / 33 tracks
# No Match for 171 hits and 0 tracks
# 127 / 1661 hits matched to 29 / 32 tracks
# No Match for 338 hits and 1 tracks
# 160 / 2445 hits matched to 31 / 34 tracks
# No Match for 583 hits and 3 tracks
# 101 / 1433 hits matched to 23 / 25 tracks
# No Match for 507 hits and 0 tracks
# 149 / 1009 hits matched to 29 / 34 tracks
# No Match for 246 hits and 2 tracks
# 228 / 1630 hits matched to 50 / 68 tracks
# No Match for 399 hits and 10 tracks
# 176 / 1390 hits matched to 37 / 42 tracks
# No Match for 381 hits and 4 tracks
# 107 / 907 hits matched to 22 / 27 tracks
# No Match for 257 hits and 0 tracks
# 308 / 2773 hits matched to 63 / 75 tracks
# No Match for 769 hits and 6 tracks
# 139 / 1047 hits matched to 29 / 33 tracks
# No Match for 261 hits and 3 tracks
# 238 / 1939 hits matched to 50 / 57 tracks
# No Match for 441 hits and 3 tracks
# 211 / 2053 hits matched to 44 / 51 tracks
# No Match for 471 hits and 2 tracks
# 144 / 1148 hits matched to 32 / 38 tracks
# No Match for 281 hits and 1 tracks
# 296 / 3411 hits matched to 68 / 80 tracks
# No Match for 785 hits and 7 tracks
# 183 / 2078 hits matched to 36 / 40 tracks
# No Match for 606 hits and 4 tracks
# 279 / 1938 hits matched to 66 / 71 tracks
# No Match for 498 hits and 5 tracks
# 270 / 2195 hits matched to 54 / 62 tracks
# No Match for 538 hits and 7 tracks
# 215 / 1696 hits matched to 42 / 56 tracks
# No Match for 472 hits and 11 tracks
# 102 / 1018 hits matched to 21 / 25 tracks
# No Match for 304 hits and 3 tracks
# 110 / 1817 hits matched to 27 / 33 tracks
# No Match for 554 hits and 2 tracks
# 130 / 1540 hits matched to 27 / 33 tracks
# No Match for 374 hits and 1 tracks
# 183 / 1525 hits matched to 35 / 36 tracks
# No Match for 411 hits and 0 tracks
# 167 / 1217 hits matched to 40 / 43 tracks
# No Match for 315 hits and 1 tracks
# 249 / 2209 hits matched to 49 / 60 tracks
# No Match for 612 hits and 7 tracks
# 114 / 1372 hits matched to 27 / 33 tracks
# No Match for 353 hits and 3 tracks
# 201 / 1752 hits matched to 36 / 42 tracks
# No Match for 476 hits and 2 tracks
# 217 / 2103 hits matched to 43 / 61 tracks
# No Match for 441 hits and 10 tracks
# 187 / 1663 hits matched to 39 / 43 tracks
# No Match for 342 hits and 3 tracks
# 175 / 931 hits matched to 36 / 41 tracks
# No Match for 230 hits and 3 tracks
# 137 / 775 hits matched to 33 / 35 tracks
# No Match for 163 hits and 2 tracks
# 166 / 2174 hits matched to 35 / 42 tracks
# No Match for 689 hits and 2 tracks
# 130 / 1492 hits matched to 28 / 31 tracks
# No Match for 427 hits and 0 tracks
# 241 / 1795 hits matched to 52 / 56 tracks
# No Match for 495 hits and 2 tracks
# 65 / 749 hits matched to 13 / 17 tracks
# No Match for 189 hits and 3 tracks
# 313 / 1984 hits matched to 63 / 74 tracks
# No Match for 480 hits and 6 tracks
# 335 / 2865 hits matched to 68 / 82 tracks
# No Match for 707 hits and 5 tracks
# 93 / 716 hits matched to 17 / 22 tracks
# No Match for 157 hits and 3 tracks
# 261 / 2360 hits matched to 50 / 56 tracks
# No Match for 695 hits and 4 tracks
# 212 / 1785 hits matched to 43 / 44 tracks
# No Match for 535 hits and 0 tracks
# 147 / 1418 hits matched to 30 / 37 tracks
# No Match for 273 hits and 6 tracks
# 57 / 1048 hits matched to 13 / 24 tracks
# No Match for 338 hits and 10 tracks
# 283 / 2105 hits matched to 54 / 60 tracks
# No Match for 467 hits and 5 tracks
# 187 / 1264 hits matched to 33 / 37 tracks
# No Match for 285 hits and 2 tracks
# 88 / 1044 hits matched to 18 / 20 tracks
# No Match for 281 hits and 0 tracks
# 137 / 1202 hits matched to 28 / 31 tracks
# No Match for 319 hits and 0 tracks
# 92 / 1261 hits matched to 21 / 27 tracks
# No Match for 381 hits and 0 tracks
# 213 / 1928 hits matched to 44 / 47 tracks
# No Match for 495 hits and 1 tracks
# 237 / 2279 hits matched to 50 / 59 tracks
# No Match for 563 hits and 4 tracks
# 83 / 883 hits matched to 19 / 20 tracks
# No Match for 137 hits and 1 tracks
# 171 / 1848 hits matched to 36 / 43 tracks
# No Match for 553 hits and 4 tracks
# 234 / 2408 hits matched to 53 / 60 tracks
# No Match for 659 hits and 2 tracks
# 83 / 1018 hits matched to 14 / 15 tracks
# No Match for 319 hits and 0 tracks
# 158 / 1076 hits matched to 29 / 33 tracks
# No Match for 274 hits and 4 tracks
# 199 / 1563 hits matched to 47 / 52 tracks
# No Match for 394 hits and 3 tracks
# 161 / 1026 hits matched to 35 / 36 tracks
# No Match for 213 hits and 1 tracks
# 131 / 1361 hits matched to 26 / 27 tracks
# No Match for 347 hits and 0 tracks
# 240 / 2274 hits matched to 54 / 60 tracks
# No Match for 611 hits and 3 tracks
# 185 / 1918 hits matched to 39 / 43 tracks
# No Match for 456 hits and 1 tracks
# 224 / 2974 hits matched to 44 / 56 tracks
# No Match for 871 hits and 7 tracks
# 194 / 2205 hits matched to 42 / 46 tracks
# No Match for 541 hits and 0 tracks
# 93 / 898 hits matched to 20 / 23 tracks
# No Match for 298 hits and 1 tracks
# 134 / 1256 hits matched to 25 / 31 tracks
# No Match for 364 hits and 2 tracks
# 76 / 1201 hits matched to 16 / 20 tracks
# No Match for 311 hits and 0 tracks
# 156 / 876 hits matched to 25 / 30 tracks
# No Match for 202 hits and 1 tracks
# 269 / 2066 hits matched to 57 / 63 tracks
# No Match for 577 hits and 5 tracks
# 238 / 1793 hits matched to 41 / 49 tracks
# No Match for 404 hits and 7 tracks
# 129 / 1067 hits matched to 26 / 28 tracks
# No Match for 271 hits and 1 tracks
# 219 / 2211 hits matched to 44 / 51 tracks
# No Match for 720 hits and 4 tracks
# 261 / 2402 hits matched to 55 / 61 tracks
# No Match for 650 hits and 2 tracks
# 234 / 2041 hits matched to 46 / 54 tracks
# No Match for 510 hits and 2 tracks
# 327 / 3206 hits matched to 66 / 80 tracks
# No Match for 767 hits and 9 tracks
# 220 / 1689 hits matched to 45 / 51 tracks
# No Match for 351 hits and 4 tracks
# 198 / 2226 hits matched to 38 / 43 tracks
# No Match for 529 hits and 0 tracks
# 167 / 2122 hits matched to 39 / 44 tracks
# No Match for 489 hits and 3 tracks
# 254 / 2869 hits matched to 48 / 55 tracks
# No Match for 783 hits and 3 tracks
# 135 / 1273 hits matched to 29 / 32 tracks
# No Match for 333 hits and 2 tracks
# 61 / 453 hits matched to 13 / 14 tracks
# No Match for 81 hits and 1 tracks
# 234 / 1981 hits matched to 50 / 57 tracks
# No Match for 470 hits and 5 tracks
# 89 / 973 hits matched to 20 / 21 tracks
# No Match for 234 hits and 0 tracks
# 229 / 1903 hits matched to 46 / 52 tracks
# No Match for 499 hits and 4 tracks
# 245 / 1665 hits matched to 44 / 50 tracks
# No Match for 442 hits and 2 tracks
# 127 / 1297 hits matched to 27 / 30 tracks
# No Match for 254 hits and 2 tracks
# 109 / 1125 hits matched to 23 / 25 tracks
# No Match for 240 hits and 2 tracks
# 117 / 1467 hits matched to 24 / 25 tracks
# No Match for 468 hits and 0 tracks
# 151 / 1680 hits matched to 34 / 35 tracks
# No Match for 477 hits and 1 tracks
# 202 / 2283 hits matched to 44 / 48 tracks
# No Match for 614 hits and 0 tracks
# 222 / 2019 hits matched to 50 / 58 tracks
# No Match for 630 hits and 5 tracks
# 133 / 1577 hits matched to 29 / 32 tracks
# No Match for 490 hits and 1 tracks
# 180 / 1979 hits matched to 45 / 48 tracks
# No Match for 496 hits and 2 tracks
# 49 / 1247 hits matched to 12 / 17 tracks
# No Match for 388 hits and 0 tracks
# 177 / 1555 hits matched to 38 / 39 tracks
# No Match for 381 hits and 0 tracks
# 176 / 1949 hits matched to 33 / 39 tracks
# No Match for 517 hits and 3 tracks
# 186 / 1579 hits matched to 40 / 45 tracks
# No Match for 372 hits and 3 tracks
# 231 / 2697 hits matched to 47 / 57 tracks
# No Match for 675 hits and 7 tracks
# 176 / 2085 hits matched to 41 / 49 tracks
# No Match for 514 hits and 7 tracks
# 126 / 761 hits matched to 23 / 26 tracks
# No Match for 194 hits and 0 tracks
# 280 / 2021 hits matched to 54 / 63 tracks
# No Match for 569 hits and 5 tracks
# 187 / 1781 hits matched to 33 / 39 tracks
# No Match for 548 hits and 3 tracks
# 247 / 2327 hits matched to 54 / 63 tracks
# No Match for 599 hits and 6 tracks
# 249 / 2081 hits matched to 46 / 57 tracks
# No Match for 464 hits and 11 tracks
# 314 / 3018 hits matched to 64 / 73 tracks
# No Match for 846 hits and 6 tracks
# 123 / 1286 hits matched to 24 / 34 tracks
# No Match for 323 hits and 9 tracks
# 119 / 989 hits matched to 24 / 24 tracks
# No Match for 263 hits and 0 tracks
# 245 / 2562 hits matched to 47 / 53 tracks
# No Match for 499 hits and 2 tracks
# 307 / 2208 hits matched to 60 / 64 tracks
# No Match for 556 hits and 4 tracks
# 264 / 2069 hits matched to 53 / 60 tracks
# No Match for 446 hits and 3 tracks
# 182 / 2141 hits matched to 34 / 41 tracks
# No Match for 514 hits and 5 tracks
# 144 / 1467 hits matched to 27 / 36 tracks
# No Match for 415 hits and 5 tracks
# 113 / 1002 hits matched to 24 / 27 tracks
# No Match for 265 hits and 0 tracks
# 307 / 2037 hits matched to 55 / 61 tracks
# No Match for 476 hits and 1 tracks
# 146 / 1608 hits matched to 33 / 45 tracks
# No Match for 432 hits and 3 tracks
# 204 / 2157 hits matched to 46 / 47 tracks
# No Match for 635 hits and 1 tracks
# 182 / 1479 hits matched to 38 / 42 tracks
# No Match for 410 hits and 2 tracks
# 172 / 1493 hits matched to 33 / 36 tracks
# No Match for 418 hits and 0 tracks
# 172 / 1408 hits matched to 41 / 53 tracks
# No Match for 306 hits and 9 tracks
# 181 / 1255 hits matched to 34 / 39 tracks
# No Match for 357 hits and 5 tracks
# 135 / 1454 hits matched to 28 / 37 tracks
# No Match for 393 hits and 3 tracks
# 264 / 2698 hits matched to 50 / 59 tracks
# No Match for 799 hits and 5 tracks
# 201 / 1932 hits matched to 42 / 49 tracks
# No Match for 518 hits and 1 tracks
# 119 / 1479 hits matched to 26 / 31 tracks
# No Match for 488 hits and 3 tracks
# 165 / 2382 hits matched to 36 / 44 tracks
# No Match for 672 hits and 4 tracks
# 340 / 3915 hits matched to 69 / 83 tracks
# No Match for 1035 hits and 9 tracks
# 107 / 1026 hits matched to 25 / 28 tracks
# No Match for 287 hits and 2 tracks
# 55 / 885 hits matched to 13 / 15 tracks
# No Match for 315 hits and 1 tracks
# 152 / 1285 hits matched to 38 / 38 tracks
# No Match for 385 hits and 0 tracks
# 122 / 903 hits matched to 20 / 20 tracks
# No Match for 169 hits and 0 tracks
# 181 / 1753 hits matched to 37 / 41 tracks
# No Match for 506 hits and 1 tracks
# 218 / 2289 hits matched to 48 / 55 tracks
# No Match for 612 hits and 4 tracks
# 186 / 1822 hits matched to 33 / 39 tracks
# No Match for 587 hits and 1 tracks
# 209 / 2219 hits matched to 42 / 51 tracks
# No Match for 590 hits and 7 tracks
# 141 / 2271 hits matched to 30 / 35 tracks
# No Match for 617 hits and 4 tracks
# 213 / 2152 hits matched to 46 / 56 tracks
# No Match for 519 hits and 2 tracks
# 152 / 1959 hits matched to 32 / 37 tracks
# No Match for 613 hits and 2 tracks
# 189 / 1828 hits matched to 45 / 52 tracks
# No Match for 531 hits and 5 tracks
# 247 / 2641 hits matched to 51 / 60 tracks
# No Match for 721 hits and 4 tracks
# 237 / 1616 hits matched to 39 / 42 tracks
# No Match for 421 hits and 2 tracks
# 166 / 1337 hits matched to 34 / 34 tracks
# No Match for 291 hits and 0 tracks
# 165 / 1670 hits matched to 34 / 39 tracks
# No Match for 428 hits and 0 tracks
# 247 / 2468 hits matched to 52 / 63 tracks
# No Match for 735 hits and 6 tracks
# 190 / 1775 hits matched to 39 / 43 tracks
# No Match for 462 hits and 2 tracks
# 218 / 2098 hits matched to 50 / 61 tracks
# No Match for 532 hits and 5 tracks
# 191 / 1171 hits matched to 44 / 47 tracks
# No Match for 256 hits and 2 tracks
# 240 / 2264 hits matched to 49 / 62 tracks
# No Match for 676 hits and 8 tracks
# 161 / 1316 hits matched to 32 / 38 tracks
# No Match for 357 hits and 5 tracks
# 253 / 2238 hits matched to 52 / 58 tracks
# No Match for 617 hits and 6 tracks
# 116 / 895 hits matched to 22 / 25 tracks
# No Match for 173 hits and 1 tracks
# 145 / 1297 hits matched to 28 / 30 tracks
# No Match for 266 hits and 2 tracks
# 154 / 1405 hits matched to 31 / 35 tracks
# No Match for 394 hits and 4 tracks
# 187 / 1564 hits matched to 41 / 48 tracks
# No Match for 405 hits and 5 tracks
# 374 / 3051 hits matched to 69 / 83 tracks
# No Match for 697 hits and 9 tracks
# 189 / 2113 hits matched to 32 / 35 tracks
# No Match for 622 hits and 1 tracks
# 143 / 1754 hits matched to 25 / 28 tracks
# No Match for 401 hits and 1 tracks
# 272 / 3356 hits matched to 59 / 72 tracks
# No Match for 892 hits and 8 tracks
# 217 / 2145 hits matched to 44 / 55 tracks
# No Match for 513 hits and 7 tracks
# 270 / 2207 hits matched to 58 / 73 tracks
# No Match for 535 hits and 5 tracks
# 117 / 1129 hits matched to 27 / 27 tracks
# No Match for 258 hits and 0 tracks
# 300 / 2651 hits matched to 60 / 74 tracks
# No Match for 582 hits and 10 tracks
# 226 / 1349 hits matched to 41 / 52 tracks
# No Match for 264 hits and 6 tracks
# 216 / 1869 hits matched to 47 / 53 tracks
# No Match for 486 hits and 2 tracks
# 195 / 1495 hits matched to 40 / 42 tracks
# No Match for 371 hits and 1 tracks
# 146 / 1132 hits matched to 31 / 34 tracks
# No Match for 267 hits and 1 tracks
# 117 / 1275 hits matched to 23 / 24 tracks
# No Match for 410 hits and 0 tracks
# 170 / 2367 hits matched to 41 / 52 tracks
# No Match for 683 hits and 9 tracks
# 159 / 1186 hits matched to 32 / 42 tracks
# No Match for 291 hits and 5 tracks
# 220 / 1436 hits matched to 39 / 47 tracks
# No Match for 261 hits and 3 tracks
# 131 / 2188 hits matched to 33 / 42 tracks
# No Match for 584 hits and 4 tracks
# 205 / 2259 hits matched to 47 / 53 tracks
# No Match for 609 hits and 2 tracks
# 152 / 1425 hits matched to 32 / 36 tracks
# No Match for 399 hits and 2 tracks
# 216 / 1667 hits matched to 43 / 49 tracks
# No Match for 422 hits and 3 tracks
# 283 / 2715 hits matched to 55 / 64 tracks
# No Match for 682 hits and 3 tracks
# 163 / 1071 hits matched to 30 / 35 tracks
# No Match for 255 hits and 3 tracks
# 244 / 2091 hits matched to 50 / 58 tracks
# No Match for 552 hits and 2 tracks
# 146 / 1818 hits matched to 33 / 37 tracks
# No Match for 423 hits and 2 tracks
# 224 / 1489 hits matched to 40 / 42 tracks
# No Match for 349 hits and 1 tracks
# 219 / 1886 hits matched to 45 / 51 tracks
# No Match for 492 hits and 3 tracks
# 108 / 752 hits matched to 20 / 22 tracks
# No Match for 207 hits and 2 tracks
# 206 / 1953 hits matched to 42 / 44 tracks
# No Match for 495 hits and 1 tracks
# 177 / 2152 hits matched to 38 / 40 tracks
# No Match for 544 hits and 0 tracks
# 158 / 1531 hits matched to 32 / 38 tracks
# No Match for 387 hits and 5 tracks
# 188 / 1861 hits matched to 38 / 50 tracks
# No Match for 460 hits and 10 tracks
# 194 / 2207 hits matched to 38 / 40 tracks
# No Match for 650 hits and 0 tracks
# 250 / 2524 hits matched to 48 / 55 tracks
# No Match for 741 hits and 4 tracks
# 167 / 1330 hits matched to 33 / 36 tracks
# No Match for 272 hits and 2 tracks
# 151 / 1547 hits matched to 23 / 28 tracks
# No Match for 471 hits and 4 tracks
# 257 / 2581 hits matched to 57 / 68 tracks
# No Match for 617 hits and 4 tracks
# 187 / 1884 hits matched to 38 / 43 tracks
# No Match for 419 hits and 1 tracks
# 288 / 2414 hits matched to 58 / 69 tracks
# No Match for 617 hits and 9 tracks
# 198 / 1517 hits matched to 41 / 45 tracks
# No Match for 334 hits and 2 tracks
# 154 / 1428 hits matched to 31 / 35 tracks
# No Match for 375 hits and 2 tracks
# 123 / 1554 hits matched to 31 / 37 tracks
# No Match for 466 hits and 6 tracks
# 184 / 1586 hits matched to 39 / 48 tracks
# No Match for 470 hits and 5 tracks
# 222 / 2262 hits matched to 46 / 55 tracks
# No Match for 694 hits and 4 tracks
# 340 / 2575 hits matched to 68 / 72 tracks
# No Match for 729 hits and 1 tracks
# 241 / 2285 hits matched to 55 / 60 tracks
# No Match for 690 hits and 1 tracks
# 158 / 1469 hits matched to 32 / 40 tracks
# No Match for 422 hits and 1 tracks
# 119 / 1785 hits matched to 24 / 27 tracks
# No Match for 391 hits and 0 tracks
# 189 / 1989 hits matched to 42 / 49 tracks
# No Match for 550 hits and 1 tracks
# 130 / 1272 hits matched to 25 / 26 tracks
# No Match for 309 hits and 1 tracks
# 110 / 1141 hits matched to 26 / 27 tracks
# No Match for 262 hits and 0 tracks
# 166 / 1282 hits matched to 37 / 43 tracks
# No Match for 290 hits and 2 tracks
# 135 / 944 hits matched to 24 / 28 tracks
# No Match for 156 hits and 3 tracks
# 219 / 1973 hits matched to 49 / 56 tracks
# No Match for 453 hits and 5 tracks
# 130 / 1257 hits matched to 28 / 29 tracks
# No Match for 361 hits and 1 tracks
# 240 / 2064 hits matched to 45 / 53 tracks
# No Match for 680 hits and 6 tracks
# 181 / 1470 hits matched to 33 / 43 tracks
# No Match for 385 hits and 7 tracks
# 202 / 2205 hits matched to 38 / 45 tracks
# No Match for 689 hits and 2 tracks
# 240 / 2158 hits matched to 43 / 63 tracks
# No Match for 627 hits and 14 tracks
# 337 / 2771 hits matched to 64 / 78 tracks
# No Match for 735 hits and 11 tracks
# 136 / 963 hits matched to 25 / 25 tracks
# No Match for 265 hits and 0 tracks
# 195 / 1778 hits matched to 42 / 43 tracks
# No Match for 433 hits and 1 tracks
# 184 / 1702 hits matched to 42 / 61 tracks
# No Match for 412 hits and 19 tracks
# 145 / 1278 hits matched to 29 / 31 tracks
# No Match for 377 hits and 1 tracks
# 167 / 1379 hits matched to 28 / 29 tracks
# No Match for 378 hits and 0 tracks
# 164 / 2040 hits matched to 34 / 38 tracks
# No Match for 625 hits and 3 tracks
# 118 / 1169 hits matched to 24 / 28 tracks
# No Match for 331 hits and 2 tracks
# 154 / 1602 hits matched to 32 / 34 tracks
# No Match for 451 hits and 1 tracks
# 175 / 1455 hits matched to 33 / 40 tracks
# No Match for 384 hits and 2 tracks
# 5 / 1164 hits matched to 2 / 33 tracks
# No Match for 350 hits and 31 tracks
# 104 / 965 hits matched to 22 / 24 tracks
# No Match for 235 hits and 1 tracks
# 177 / 2018 hits matched to 36 / 40 tracks
# No Match for 477 hits and 3 tracks
# 258 / 2399 hits matched to 52 / 64 tracks
# No Match for 613 hits and 9 tracks
# 155 / 2039 hits matched to 34 / 39 tracks
# No Match for 510 hits and 2 tracks
# 256 / 2201 hits matched to 48 / 57 tracks
# No Match for 645 hits and 4 tracks
# 110 / 1184 hits matched to 26 / 30 tracks
# No Match for 330 hits and 2 tracks
# 143 / 1692 hits matched to 30 / 39 tracks
# No Match for 448 hits and 4 tracks
# 48 / 728 hits matched to 8 / 8 tracks
# No Match for 131 hits and 0 tracks
# 154 / 1876 hits matched to 35 / 44 tracks
# No Match for 600 hits and 5 tracks
# 131 / 908 hits matched to 22 / 26 tracks
# No Match for 268 hits and 1 tracks
# 126 / 1921 hits matched to 28 / 31 tracks
# No Match for 559 hits and 2 tracks
# 138 / 2150 hits matched to 32 / 43 tracks
# No Match for 578 hits and 6 tracks
# 236 / 2543 hits matched to 56 / 63 tracks
# No Match for 624 hits and 6 tracks
# 259 / 2023 hits matched to 50 / 58 tracks
# No Match for 620 hits and 4 tracks
# 217 / 1923 hits matched to 43 / 46 tracks
# No Match for 367 hits and 1 tracks
# 99 / 735 hits matched to 24 / 27 tracks
# No Match for 121 hits and 2 tracks
# 73 / 694 hits matched to 19 / 19 tracks
# No Match for 155 hits and 0 tracks
# 113 / 1145 hits matched to 22 / 25 tracks
# No Match for 238 hits and 2 tracks
# 133 / 980 hits matched to 25 / 32 tracks
# No Match for 324 hits and 2 tracks
# 141 / 1783 hits matched to 31 / 40 tracks
# No Match for 581 hits and 1 tracks
# 245 / 2106 hits matched to 52 / 57 tracks
# No Match for 569 hits and 2 tracks
# 123 / 1633 hits matched to 26 / 31 tracks
# No Match for 478 hits and 1 tracks
# 187 / 1736 hits matched to 39 / 45 tracks
# No Match for 443 hits and 6 tracks
# 115 / 1428 hits matched to 24 / 25 tracks
# No Match for 396 hits and 0 tracks
# 97 / 1130 hits matched to 24 / 29 tracks
# No Match for 271 hits and 4 tracks
# 145 / 1237 hits matched to 34 / 39 tracks
# No Match for 265 hits and 4 tracks
# 304 / 2910 hits matched to 64 / 72 tracks
# No Match for 804 hits and 4 tracks
# 319 / 1926 hits matched to 66 / 74 tracks
# No Match for 459 hits and 7 tracks
# 245 / 2302 hits matched to 48 / 57 tracks
# No Match for 650 hits and 6 tracks
# 94 / 1472 hits matched to 21 / 25 tracks
# No Match for 507 hits and 2 tracks
# 180 / 1863 hits matched to 38 / 39 tracks
# No Match for 494 hits and 0 tracks
# 275 / 1676 hits matched to 59 / 65 tracks
# No Match for 429 hits and 4 tracks
# 95 / 1369 hits matched to 20 / 20 tracks
# No Match for 333 hits and 0 tracks
# 171 / 1191 hits matched to 34 / 40 tracks
# No Match for 284 hits and 6 tracks
# 196 / 2660 hits matched to 37 / 44 tracks
# No Match for 712 hits and 4 tracks
# 272 / 2658 hits matched to 57 / 64 tracks
# No Match for 656 hits and 3 tracks
# 141 / 1464 hits matched to 32 / 35 tracks
# No Match for 410 hits and 2 tracks
# 78 / 1357 hits matched to 18 / 22 tracks
# No Match for 386 hits and 0 tracks
# 319 / 2391 hits matched to 62 / 67 tracks
# No Match for 644 hits and 4 tracks
# 200 / 2062 hits matched to 42 / 50 tracks
# No Match for 545 hits and 2 tracks
# 103 / 797 hits matched to 17 / 19 tracks
# No Match for 234 hits and 1 tracks
# 123 / 1424 hits matched to 27 / 34 tracks
# No Match for 352 hits and 7 tracks
# 63 / 814 hits matched to 11 / 13 tracks
# No Match for 202 hits and 2 tracks
# 134 / 1843 hits matched to 29 / 34 tracks
# No Match for 512 hits and 4 tracks
# 139 / 2299 hits matched to 27 / 36 tracks
# No Match for 774 hits and 5 tracks
# 173 / 1706 hits matched to 36 / 43 tracks
# No Match for 420 hits and 6 tracks
# 86 / 918 hits matched to 20 / 22 tracks
# No Match for 316 hits and 0 tracks
# 102 / 686 hits matched to 19 / 21 tracks
# No Match for 170 hits and 2 tracks
# 237 / 1747 hits matched to 51 / 60 tracks
# No Match for 483 hits and 6 tracks
# 148 / 1088 hits matched to 27 / 31 tracks
# No Match for 279 hits and 3 tracks
# 235 / 1691 hits matched to 41 / 52 tracks
# No Match for 483 hits and 7 tracks
# 345 / 2585 hits matched to 66 / 74 tracks
# No Match for 777 hits and 2 tracks
# 211 / 2274 hits matched to 43 / 48 tracks
# No Match for 497 hits and 3 tracks
# 230 / 2193 hits matched to 48 / 67 tracks
# No Match for 626 hits and 10 tracks
# 145 / 1596 hits matched to 33 / 34 tracks
# No Match for 539 hits and 1 tracks
# 198 / 2159 hits matched to 43 / 46 tracks
# No Match for 593 hits and 2 tracks
# 173 / 1854 hits matched to 37 / 42 tracks
# No Match for 491 hits and 2 tracks
# 118 / 1157 hits matched to 26 / 28 tracks
# No Match for 302 hits and 1 tracks
# 192 / 1907 hits matched to 36 / 43 tracks
# No Match for 567 hits and 4 tracks
# 202 / 1618 hits matched to 39 / 45 tracks
# No Match for 428 hits and 4 tracks
# 296 / 2574 hits matched to 54 / 64 tracks
# No Match for 656 hits and 4 tracks
# 186 / 1945 hits matched to 36 / 44 tracks
# No Match for 515 hits and 5 tracks
# 155 / 1768 hits matched to 35 / 45 tracks
# No Match for 377 hits and 4 tracks
# 176 / 1272 hits matched to 34 / 42 tracks
# No Match for 315 hits and 3 tracks
# 162 / 1989 hits matched to 27 / 29 tracks
# No Match for 525 hits and 2 tracks
# 132 / 1588 hits matched to 26 / 32 tracks
# No Match for 443 hits and 3 tracks
# 273 / 2290 hits matched to 57 / 65 tracks
# No Match for 598 hits and 2 tracks
# 56 / 571 hits matched to 14 / 14 tracks
# No Match for 170 hits and 0 tracks
# 99 / 1396 hits matched to 23 / 25 tracks
# No Match for 387 hits and 1 tracks
# 245 / 1869 hits matched to 42 / 51 tracks
# No Match for 493 hits and 3 tracks
# 156 / 1134 hits matched to 26 / 30 tracks
# No Match for 270 hits and 0 tracks
# 228 / 2345 hits matched to 46 / 57 tracks
# No Match for 596 hits and 6 tracks
# 182 / 1881 hits matched to 39 / 46 tracks
# No Match for 430 hits and 5 tracks
# 125 / 1452 hits matched to 25 / 33 tracks
# No Match for 390 hits and 5 tracks
# 83 / 945 hits matched to 16 / 22 tracks
# No Match for 164 hits and 5 tracks
# 112 / 1023 hits matched to 27 / 28 tracks
# No Match for 267 hits and 0 tracks
# 57 / 1053 hits matched to 13 / 16 tracks
# No Match for 357 hits and 1 tracks
# 169 / 1851 hits matched to 38 / 49 tracks
# No Match for 536 hits and 8 tracks
# 159 / 1264 hits matched to 34 / 36 tracks
# No Match for 241 hits and 1 tracks
# 94 / 907 hits matched to 18 / 20 tracks
# No Match for 267 hits and 1 tracks
# 224 / 2662 hits matched to 41 / 52 tracks
# No Match for 784 hits and 5 tracks
# 216 / 1825 hits matched to 41 / 44 tracks
# No Match for 538 hits and 2 tracks
# 166 / 2374 hits matched to 34 / 39 tracks
# No Match for 634 hits and 2 tracks
# 166 / 1837 hits matched to 34 / 37 tracks
# No Match for 459 hits and 0 tracks
# 147 / 2198 hits matched to 35 / 45 tracks
# No Match for 628 hits and 3 tracks
# 178 / 1723 hits matched to 37 / 45 tracks
# No Match for 465 hits and 2 tracks
# 230 / 2157 hits matched to 49 / 54 tracks
# No Match for 563 hits and 2 tracks
# 196 / 1866 hits matched to 42 / 47 tracks
# No Match for 509 hits and 3 tracks
# 167 / 1289 hits matched to 33 / 36 tracks
# No Match for 293 hits and 1 tracks
# 207 / 1519 hits matched to 41 / 48 tracks
# No Match for 355 hits and 6 tracks
# 151 / 1663 hits matched to 33 / 43 tracks
# No Match for 337 hits and 2 tracks
# 136 / 1660 hits matched to 26 / 31 tracks
# No Match for 422 hits and 0 tracks
# 237 / 2289 hits matched to 47 / 52 tracks
# No Match for 577 hits and 3 tracks
# 134 / 1335 hits matched to 30 / 33 tracks
# No Match for 385 hits and 0 tracks
# 237 / 1606 hits matched to 43 / 45 tracks
# No Match for 327 hits and 0 tracks
# 178 / 2143 hits matched to 40 / 48 tracks
# No Match for 467 hits and 4 tracks
# 223 / 2165 hits matched to 40 / 47 tracks
# No Match for 601 hits and 2 tracks
# 221 / 1376 hits matched to 35 / 41 tracks
# No Match for 323 hits and 3 tracks
# 236 / 2557 hits matched to 46 / 52 tracks
# No Match for 751 hits and 1 tracks
# 219 / 1633 hits matched to 44 / 45 tracks
# No Match for 451 hits and 0 tracks
# 261 / 2504 hits matched to 50 / 55 tracks
# No Match for 725 hits and 0 tracks
# 128 / 1425 hits matched to 26 / 32 tracks
# No Match for 359 hits and 1 tracks
# 216 / 1882 hits matched to 41 / 43 tracks
# No Match for 416 hits and 1 tracks
# 195 / 1679 hits matched to 39 / 42 tracks
# No Match for 420 hits and 0 tracks
# 125 / 1303 hits matched to 27 / 32 tracks
# No Match for 278 hits and 1 tracks
# 229 / 1954 hits matched to 43 / 51 tracks
# No Match for 562 hits and 6 tracks
# 250 / 2301 hits matched to 41 / 42 tracks
# No Match for 635 hits and 1 tracks
# 111 / 869 hits matched to 25 / 26 tracks
# No Match for 190 hits and 1 tracks
# 210 / 2192 hits matched to 42 / 51 tracks
# No Match for 557 hits and 4 tracks
# 215 / 2505 hits matched to 48 / 53 tracks
# No Match for 668 hits and 4 tracks
# 212 / 2787 hits matched to 47 / 54 tracks
# No Match for 745 hits and 3 tracks
# 177 / 1979 hits matched to 41 / 44 tracks
# No Match for 579 hits and 1 tracks
# 115 / 1175 hits matched to 29 / 32 tracks
# No Match for 309 hits and 0 tracks
# 124 / 1707 hits matched to 31 / 35 tracks
# No Match for 465 hits and 2 tracks
# 154 / 1027 hits matched to 26 / 36 tracks
# No Match for 203 hits and 10 tracks
# 152 / 1051 hits matched to 34 / 37 tracks
# No Match for 232 hits and 2 tracks
# 133 / 2058 hits matched to 35 / 54 tracks
# No Match for 518 hits and 8 tracks
# No hits matched for event----------------------- 406
# 130 / 1402 hits matched to 24 / 28 tracks
# No Match for 325 hits and 1 tracks
# 182 / 2025 hits matched to 41 / 47 tracks
# No Match for 483 hits and 4 tracks
# 147 / 1032 hits matched to 28 / 34 tracks
# No Match for 231 hits and 4 tracks
# 156 / 1911 hits matched to 32 / 40 tracks
# No Match for 507 hits and 3 tracks
# 320 / 2721 hits matched to 66 / 75 tracks
# No Match for 749 hits and 4 tracks
# 153 / 1497 hits matched to 29 / 37 tracks
# No Match for 328 hits and 7 tracks
# 100 / 1259 hits matched to 18 / 19 tracks
# No Match for 441 hits and 1 tracks
# 150 / 1682 hits matched to 33 / 38 tracks
# No Match for 539 hits and 1 tracks
# 211 / 1848 hits matched to 48 / 53 tracks
# No Match for 465 hits and 4 tracks
# 151 / 1922 hits matched to 37 / 42 tracks
# No Match for 544 hits and 5 tracks
# 165 / 1243 hits matched to 32 / 32 tracks
# No Match for 279 hits and 0 tracks
# 137 / 1249 hits matched to 28 / 32 tracks
# No Match for 388 hits and 4 tracks
# 148 / 1694 hits matched to 27 / 34 tracks
# No Match for 534 hits and 6 tracks
# 211 / 2441 hits matched to 41 / 48 tracks
# No Match for 709 hits and 3 tracks
# 195 / 2466 hits matched to 40 / 44 tracks
# No Match for 845 hits and 4 tracks
# 174 / 1485 hits matched to 34 / 39 tracks
# No Match for 411 hits and 1 tracks
# 197 / 1408 hits matched to 37 / 40 tracks
# No Match for 312 hits and 0 tracks
# 183 / 1723 hits matched to 34 / 41 tracks
# No Match for 503 hits and 4 tracks
# 338 / 3468 hits matched to 53 / 81 tracks
# No Match for 746 hits and 26 tracks
# 81 / 1177 hits matched to 16 / 28 tracks
# No Match for 352 hits and 10 tracks
# 291 / 2253 hits matched to 59 / 65 tracks
# No Match for 482 hits and 5 tracks
# 155 / 1095 hits matched to 30 / 32 tracks
# No Match for 227 hits and 0 tracks
# 263 / 2368 hits matched to 50 / 56 tracks
# No Match for 597 hits and 2 tracks
# 85 / 751 hits matched to 20 / 24 tracks
# No Match for 147 hits and 2 tracks
# 234 / 1968 hits matched to 45 / 52 tracks
# No Match for 481 hits and 5 tracks
# 99 / 1089 hits matched to 20 / 27 tracks
# No Match for 300 hits and 5 tracks
# 166 / 1965 hits matched to 36 / 47 tracks
# No Match for 529 hits and 8 tracks
# 139 / 1661 hits matched to 29 / 30 tracks
# No Match for 435 hits and 0 tracks
# 242 / 2905 hits matched to 52 / 62 tracks
# No Match for 729 hits and 6 tracks
# 158 / 1256 hits matched to 27 / 28 tracks
# No Match for 272 hits and 0 tracks
# 169 / 1260 hits matched to 35 / 37 tracks
# No Match for 325 hits and 0 tracks
# 72 / 1206 hits matched to 12 / 16 tracks
# No Match for 298 hits and 2 tracks
# 59 / 977 hits matched to 15 / 17 tracks
# No Match for 329 hits and 0 tracks
# 219 / 1513 hits matched to 50 / 63 tracks
# No Match for 304 hits and 9 tracks
# 238 / 1450 hits matched to 49 / 60 tracks
# No Match for 327 hits and 8 tracks
# 96 / 1594 hits matched to 17 / 20 tracks
# No Match for 488 hits and 2 tracks
# 209 / 2020 hits matched to 44 / 53 tracks
# No Match for 442 hits and 6 tracks
# 275 / 1945 hits matched to 53 / 63 tracks
# No Match for 512 hits and 4 tracks
# 363 / 3177 hits matched to 73 / 76 tracks
# No Match for 822 hits and 2 tracks
# 249 / 2088 hits matched to 49 / 57 tracks
# No Match for 560 hits and 5 tracks
# 202 / 1970 hits matched to 46 / 52 tracks
# No Match for 544 hits and 3 tracks
# 130 / 1155 hits matched to 28 / 29 tracks
# No Match for 292 hits and 0 tracks
# 291 / 2510 hits matched to 56 / 61 tracks
# No Match for 607 hits and 3 tracks
# 224 / 2058 hits matched to 45 / 47 tracks
# No Match for 578 hits and 2 tracks
# 170 / 1654 hits matched to 36 / 37 tracks
# No Match for 356 hits and 1 tracks
# 252 / 1951 hits matched to 52 / 60 tracks
# No Match for 431 hits and 6 tracks
# 147 / 1687 hits matched to 31 / 34 tracks
# No Match for 556 hits and 2 tracks
# 134 / 1147 hits matched to 29 / 32 tracks
# No Match for 273 hits and 2 tracks
# 331 / 2196 hits matched to 65 / 71 tracks
# No Match for 565 hits and 5 tracks
# 194 / 1700 hits matched to 36 / 40 tracks
# No Match for 464 hits and 3 tracks
# 147 / 1817 hits matched to 31 / 36 tracks
# No Match for 531 hits and 1 tracks
# 142 / 1328 hits matched to 30 / 35 tracks
# No Match for 338 hits and 1 tracks
# 83 / 659 hits matched to 16 / 18 tracks
# No Match for 146 hits and 0 tracks
# 136 / 1044 hits matched to 29 / 30 tracks
# No Match for 261 hits and 0 tracks
# 160 / 2303 hits matched to 34 / 40 tracks
# No Match for 723 hits and 2 tracks
# 144 / 1787 hits matched to 32 / 38 tracks
# No Match for 512 hits and 5 tracks
# 216 / 2145 hits matched to 44 / 47 tracks
# No Match for 546 hits and 2 tracks
# 218 / 2548 hits matched to 42 / 50 tracks
# No Match for 818 hits and 1 tracks
# 80 / 1299 hits matched to 15 / 17 tracks
# No Match for 340 hits and 1 tracks
# 141 / 1616 hits matched to 25 / 27 tracks
# No Match for 450 hits and 1 tracks
# 195 / 1741 hits matched to 34 / 35 tracks
# No Match for 554 hits and 1 tracks
# 199 / 1671 hits matched to 40 / 43 tracks
# No Match for 494 hits and 1 tracks
# 278 / 2204 hits matched to 59 / 64 tracks
# No Match for 458 hits and 2 tracks
# 254 / 2872 hits matched to 51 / 57 tracks
# No Match for 820 hits and 5 tracks
# 115 / 1321 hits matched to 24 / 28 tracks
# No Match for 300 hits and 4 tracks
# 121 / 1118 hits matched to 23 / 27 tracks
# No Match for 302 hits and 3 tracks
# 172 / 2217 hits matched to 38 / 41 tracks
# No Match for 515 hits and 0 tracks
# 113 / 1405 hits matched to 23 / 28 tracks
# No Match for 350 hits and 0 tracks
# 135 / 1292 hits matched to 24 / 32 tracks
# No Match for 405 hits and 1 tracks
# 180 / 1652 hits matched to 36 / 42 tracks
# No Match for 516 hits and 5 tracks
# 204 / 1888 hits matched to 39 / 45 tracks
# No Match for 454 hits and 2 tracks
# No hits matched for event----------------------- 478
# 291 / 1616 hits matched to 59 / 70 tracks
# No Match for 409 hits and 5 tracks
# 169 / 1710 hits matched to 37 / 44 tracks
# No Match for 469 hits and 5 tracks
# 335 / 3033 hits matched to 75 / 86 tracks
# No Match for 760 hits and 10 tracks
# 193 / 1178 hits matched to 47 / 57 tracks
# No Match for 252 hits and 7 tracks
# 285 / 2376 hits matched to 55 / 64 tracks
# No Match for 662 hits and 4 tracks
# 128 / 1139 hits matched to 28 / 29 tracks
# No Match for 300 hits and 0 tracks
# 204 / 1709 hits matched to 39 / 46 tracks
# No Match for 414 hits and 6 tracks
# 141 / 1238 hits matched to 25 / 25 tracks
# No Match for 398 hits and 0 tracks
# 259 / 2014 hits matched to 50 / 56 tracks
# No Match for 449 hits and 4 tracks
# 113 / 1105 hits matched to 25 / 32 tracks
# No Match for 274 hits and 4 tracks
# 285 / 2737 hits matched to 53 / 64 tracks
# No Match for 738 hits and 6 tracks
# 149 / 1588 hits matched to 29 / 37 tracks
# No Match for 451 hits and 2 tracks
# 182 / 1147 hits matched to 41 / 44 tracks
# No Match for 172 hits and 0 tracks
# 194 / 1366 hits matched to 42 / 48 tracks
# No Match for 335 hits and 4 tracks
# 217 / 2438 hits matched to 44 / 47 tracks
# No Match for 630 hits and 3 tracks
# No hits matched for event----------------------- 494
# 203 / 1991 hits matched to 40 / 43 tracks
# No Match for 549 hits and 2 tracks
# 280 / 2200 hits matched to 50 / 57 tracks
# No Match for 602 hits and 2 tracks
# 112 / 1206 hits matched to 22 / 22 tracks
# No Match for 245 hits and 0 tracks
# 111 / 1986 hits matched to 24 / 28 tracks
# No Match for 582 hits and 3 tracks
# 159 / 2154 hits matched to 31 / 34 tracks
# No Match for 613 hits and 2 tracks
#
# 91198 / 878758 hits matched to 18623 / 21791 tracks
#
# 440 hits with zero TP of total 1702 hits and 0 / 52 matched tracks
# 557 hits with zero TP of total 2228 hits and 0 / 60 matched tracks
# 213 hits with zero TP of total 678 hits and 0 / 21 matched tracks
# 734 hits with zero TP of total 2799 hits and 0 / 64 matched tracks
# 762 hits with zero TP of total 2599 hits and 0 / 61 matched tracks
#
# Event 10
# TP = 0: 0 hits and 0 tracks
# No Rechit TP Match for 440 / 1702 hits
# No Track TP Match: 52 / 52 tracks
#
# Event 40
# TP = 0: 3 hits and 0 tracks
# No Rechit TP Match for 557 / 2228 hits
# No Track TP Match: 60 / 60 tracks
#
# Event 406
# TP = 0: 8 hits and 0 tracks
# No Rechit TP Match for 213 / 678 hits
# No Track TP Match: 21 / 21 tracks
#
# Event 478
# TP = 0: 4 hits and 0 tracks
# No Rechit TP Match for 734 / 2799 hits
# No Track TP Match: 64 / 64 tracks
#
# Event 494
# TP = 0: 6 hits and 0 tracks
# No Rechit TP Match for 762 / 2599 hits
# No Track TP Match: 61 / 61 tracks

# %%
for i, key in zip(range(5), ["trackEta", "trackPhi", "qoverp", "dxy", "dsz"]):
    track_param_ = data_.array(key)
    unmatched_data_ = []
    concat_track_param_ = []
    print "Iterating over", key
    
    for j in range(len(track_param_)):
        if j in unmatched_event_numbers_:
            # Use the event number from the stored data for the event with no matched tracks
            unmatched_data_.extend(track_param_[j])
        else:
            concat_track_param_.extend(track_param_[j])
    
    print "Number of elements:", len(concat_track_param_)
    ax_ = plt.subplot()        
        
    # Plot that single element on the histogram in a different color
    plt.hist(unmatched_data_, histtype='bar', bins=20, align='mid', orientation='vertical', color='red', alpha=0.5, label='unmatched')

    #plt.hist([unmatched_data_, concat_track_param_], histtype='bar', bins=20, align='mid', orientation='vertical', alpha=0.5, label=['unmatched', 'matched'])
    plt.hist(concat_track_param_, histtype='bar', bins=20, align='mid', orientation='vertical', alpha=0.5, label='matched')
    
    plt.legend(loc='upper right')
    plt.ylabel('Frequency')
    plt.yscale('log')
    plt.xlabel('Distribution of ' + key)
    plt.title(key + ' Distribution')
    # plt.savefig('plots/' + gen_event_ + '/track/' + key)
    plt.show()
# Out:
# Iterating over trackEta
# Number of elements: 21533
# Iterating over trackPhi
# Number of elements: 21533
# Iterating over qoverp
# Number of elements: 21533
# Iterating over dxy
# Number of elements: 21533
# Iterating over dsz
# Number of elements: 21533

# %%
track_eta_ = data_.array('trackEta')

for i, key in zip(range(5), ["trackEta", "trackPhi", "qoverp", "dxy", "dsz"]):
    track_param_ = data_.array(key)
    print "Iterating over", key

    
    discarded_track_param_ = []
    concat_track_param_ = []
    unmatched_track_param_ = []

    for j in range(len(track_param_)):
        for k in range(len(track_param_[j])):
            
            # Constrain the track eta value
            if track_eta_[j][k] < 0.9 and track_eta_[j][k] > (-0.9):
                if j in unmatched_event_numbers_:
                    unmatched_track_param_.append(track_param_[j][k])
                else:
                    concat_track_param_.append(track_param_[j][k])
            else:
                discarded_track_param_.append(track_param_[j][k])
    
    print "Discarded", len(discarded_track_param_), "and matched", len(concat_track_param_), "/", 
    print len(concat_track_param_)+len(unmatched_track_param_), "tracks"
    ax_ = plt.subplot()
    
    # Plot that single element on the histogram in a different color
    plt.hist(unmatched_track_param_, histtype='bar', bins=40, align='mid', orientation='vertical', color='red', alpha=0.5, label='unmatched')

    #plt.hist([unmatched_data_, concat_track_param_], histtype='bar', bins=20, align='mid', orientation='vertical', alpha=0.5, label=['unmatched', 'matched'])
    plt.hist(concat_track_param_, histtype='bar', bins=40, align='mid', orientation='vertical', alpha=0.5, label='matched')
    plt.hist(discarded_track_param_, histtype='bar', bins=40, align='mid', orientation='vertical', alpha=0.2, color='green', label='discarded')
    plt.legend(loc='upper right')
    plt.ylabel('Frequency')
    plt.yscale('log')
    plt.xlabel('Distribution of ' + key)
    plt.title(key + ' Distribution')
    plt.savefig('plots/' + gen_event_ + '/track/etabound-' + key)
    plt.show()
# Out:
# Iterating over trackEta
# Discarded 13674 and matched 8016 / 8117 tracks
# Iterating over trackPhi
# Discarded 13674 and matched 8016 / 8117 tracks
# Iterating over qoverp
# Discarded 13674 and matched 8016 / 8117 tracks
# Iterating over dxy
# Discarded 13674 and matched 8016 / 8117 tracks
# Iterating over dsz
# Discarded 13674 and matched 8016 / 8117 tracks

# %%
track_pt_ = data_.array('trackPt').tolist()
track_eta_ = data_.array('trackEta').tolist()
concat_track_pt_ = []
unmatched_track_pt_ = []
discarded_track_pt_= []

discarded_index_map_ = []

for j in range(len(track_pt_)):
    for k in range(len(track_pt_[j])):
       
        # Constrain the track eta value
        if track_eta_[j][k] < 0.9 and track_eta_[j][k] > (-0.9):
            if j in unmatched_event_numbers_:
                unmatched_track_pt_.append(track_pt_[j][k])
            else:
                concat_track_pt_.append(track_pt_[j][k])
        else:
            discarded_track_pt_.append(track_pt_[j][k])


print "Discarded", len(discarded_track_pt_), "and matched", len(concat_track_pt_), "/", len(concat_track_pt_) + len(unmatched_track_pt_), "tracks"
plt.hist(concat_track_pt_, histtype='bar', bins=20, align='mid', orientation='vertical', alpha=0.3, label='matched')
plt.hist(unmatched_track_pt_, histtype='bar', bins=20, align='mid', orientation='vertical', alpha=0.4, label='unmatched')
plt.hist(discarded_track_pt_, histtype='bar', bins=20, align='mid', orientation='vertical', alpha=0.2, label='discarded')
plt.legend(loc='upper right')
plt.ylabel('Frequency')
plt.xlabel('Distribution of pt')
plt.xscale('log')
plt.yscale('log')
plt.title('Track pt Distribution')
plt.savefig('plots/' + gen_event_ + '/track/etabound-trackpt-logscale')
plt.show()
# Out:
# Discarded 13674 and matched 8016 / 8117 tracks

# %%
# Check that the arrays are of equal lengths - i.e. each point has an index and an x, y, z coordinate
for i in range(len(stereo_tp_idx_)):
    #print len(stereo_tp_idx_[i]), len(stereo_x_[i])
    if len(stereo_tp_idx_[i]) != len(stereo_x_[i]) or len(stereo_tp_idx_[i]) != len(stereo_y_[i]) or len(stereo_tp_idx_[i]) != len(stereo_z_[i]):
        print "Length of indices and points does not match"
        if len(stereo_tp_idx_[i]) > len(stereo_x_[i]):
            print "There are", len(stereo_tp_idx_[i]) - len(stereo_x_[i]), "less hits than clusters"
        else:
            print "There are no cluster indices (even -1) for", len(stereo_x_[i]) - len(stereo_tp_idx_[i]), "hits"

# %%
total_tracks_ = sum([len(track) for track in track_tp_idx_])
print "Total tracks: ", total_tracks_
# Out:
# Total tracks:  21791

# %%
# associate a global track index for each rechit
'''
track_index_ = 0
x_counter_ = 0
rechit_track_map_ = {}
track_event_map_ = {}

for event in range(len(stereo_tp_idx_)):
    
    # Check if for that event that hit has a value of matched = 1
    for hitIndex in range(len(matched_stereo_rechit_[event])):
        
        if matched_stereo_rechit_[event][hitIndex] == 1:
            if stereo_tp_idx_[event][hitIndex] == -1:
                x_counter_+=1
                 
            else:
                
                # This means that hit has been matched to a track
                # Now associate a unique ID to that track index and
                # add that row into the rechit map
                unique_id_ = (event, stereo_tp_idx_[event][hitIndex])
            
            # Store the rechit properties on a per-track basis in a map
            # corresponding to one single track ID per list of rechit properties
            if unique_id_ in track_event_map_:
                # This means there is already a list at that value
                # You can add r, phi, eta, and whatever we need to store
                rechit_track_map_[track_event_map_[unique_id_]].append(
                    [stereo_x_[event][hitIndex], stereo_y_[event][hitIndex], stereo_z_[event][hitIndex]])
            else:
                # This means we need to create a list at that value
                track_event_map_[unique_id_] = track_index_
                track_index_ += 1
                # You can add r, phi, eta, and whatever we need to store
                rechit_track_map_[track_event_map_[unique_id_]] = []
                rechit_track_map_[track_event_map_[unique_id_]].append(
                    [stereo_x_[event][hitIndex], stereo_y_[event][hitIndex], stereo_z_[event][hitIndex]])
'''

# %%
# Ignore the matched flag column because the current data does not have the correct length

# associate a global track index for each rechit
track_index_ = 0
hitmatch_ = 0
rechit_track_map_ = {}
track_event_map_ = {}
nomatch_ = 0
total_rechits_ = 0

for event_ in range(len(stereo_tp_idx_)):
    
    # Check if for that event that hit has a value of matched = 1
    for hitIndex_ in range(len(matched_stereo_rechit_[event_])):
        total_rechits_+=1
        if stereo_tp_idx_[event_][hitIndex_] != -1 and stereo_tp_idx_[event_][hitIndex_] in track_tp_idx_[event_]: 
            hitmatch_+=1
                          
            # This means that hit has been matched to a track
            # Now associate a unique ID to that track index and
            # add that row into the rechit map
            unique_id_ = (event_, stereo_tp_idx_[event_][hitIndex_])
            
            # Store the rechit properties on a per-track basis in a map
            # corresponding to one single track ID per list of rechit properties
            if unique_id_ in track_event_map_:
                # This means there is already a list at that value
                # You can add r, phi, eta, and whatever we need to store
                rechit_track_map_[track_event_map_[unique_id_]].append(
                    [stereo_x_[event_][hitIndex_], stereo_y_[event_][hitIndex_], stereo_z_[event_][hitIndex_]])
            else:
                # This means we need to create a list at that value
                track_event_map_[unique_id_] = track_index_
                track_index_ += 1
                # You can add r, phi, eta, and whatever we need to store
                rechit_track_map_[track_event_map_[unique_id_]] = []
                rechit_track_map_[track_event_map_[unique_id_]].append(
                    [stereo_x_[event_][hitIndex_], stereo_y_[event_][hitIndex_], stereo_z_[event_][hitIndex_]])
        else:
            nomatch_+=1

# %%
print "Tracks matched for", hitmatch_, "of", total_rechits_, "rechits"
# Out:
# Tracks matched for 41075 of 321235 rechits

# %%
# This is a test to be used in case we utilise a matchedHit column in our code
x_counter_=0
matched_stereo_rechit_ = data_.array('stereoHitMatch')
for event_number_ in range(len(stereo_tp_idx_)):
    if len(matched_stereo_rechit_[event_number_]) != len(stereo_tp_idx_[event_number_]):
        print "The number of matched+unmatched and total hits does not tally"
        print "This is an issue for C++!"
        break
# Out:
# The number of matched+unmatched and total hits does not tally
# This is an issue for C++!

# %%
for event_ in range(len(matched_stereo_rechit_)):
    for match_ in range(len(matched_stereo_rechit_[event_])):
        if stereo_tp_idx_[event_][match_]==1:
            if stereo_tp_idx_[event_][match_]==-1:
                print "Problem at", event_, match_
                break
            else:
                continue

# %%
#for key in sorted(track_event_map_):
#    print key, track_event_map_[key]    
print len(track_event_map_.keys())
# Out:
# [(289, 22), (261, 146), (171, 86), (427, 224), (67, 137), (233, 657), (397, 520), (53, 166), (470, 215), (355, 898), (318, 26), (265, 110), (341, 219), (214, 91), (440, 132), (223, 155), (66, 66), (449, 74), (372, 656), (15, 143), (398, 61), (445, 194), (481, 601), (8, 87), (467, 538), (393, 387), (303, 128), (109, 177), (336, 23), (95, 98), (118, 129), (65, 11), (411, 35), (87, 191), (106, 1125), (291, 601), (346, 532), (293, 11), (136, 330), (122, 63), (175, 43), (466, 646), (108, 126), (454, 22), (221, 313), (424, 69), (387, 91), (320, 22), (230, 553), (255, 78), (98, 407), (45, 764), (250, 330), (54, 586), (93, 144), (386, 48), (139, 456), (12, 90), (231, 38), (268, 44), (141, 314), (14, 568), (291, 149), (425, 1195), (97, 70), (480, 74), (83, 23), (339, 129), (16, 172), (311, 127), (244, 2), (230, 117), (372, 876), (163, 60), (456, 50), (82, 52), (45, 64), (301, 214), (340, 908), (384, 174), (77, 367), (370, 507), (206, 109), (499, 229), (84, 1213), (176, 0), (485, 26), (418, 69), (238, 322), (42, 617), (404, 16), (443, 506), (7, 149), (390, 39), (263, 303), (460, 162), (323, 64), (106, 336), (0, 109), (219, 19), (152, 88), (11, 303), (380, 6), (327, 521), (315, 917), (209, 234), (473, 54), (66, 277), (26, 837), (324, 717), (327, 861), (167, 49), (190, 146), (469, 92), (56, 146), (111, 372), (5, 39), (298, 51), (171, 195), (178, 605), (436, 165), (76, 124), (459, 76), (355, 15), (228, 263), (415, 809), (87, 604), (327, 77), (483, 101), (449, 199), (89, 104), (472, 96), (181, 568), (75, 13), (421, 105), (203, 167), (84, 309), (257, 677), (222, 95), (294, 446), (139, 697), (360, 708), (166, 390), (173, 410), (249, 76), (175, 188), (468, 170), (235, 97), (198, 119), (182, 616), (364, 267), (348, 640), (168, 38), (424, 176), (64, 119), (410, 111), (359, 0), (425, 196), (22, 176), (3, 261), (386, 135), (409, 94), (282, 468), (102, 253), (254, 8), (291, 30), (99, 64), (261, 698), (120, 44), (173, 94), (233, 243), (445, 52), (16, 807), (307, 40), (169, 228), (25, 31), (48, 136), (11, 28), (177, 500), (200, 83), (181, 527), (479, 643), (405, 236), (45, 309), (232, 452), (105, 90), (68, 106), (414, 122), (54, 13), (310, 187), (229, 57), (266, 53), (358, 663), (148, 49), (81, 114), (134, 4), (67, 35), (450, 169), (309, 98), (340, 2), (332, 133), (377, 300), (431, 563), (124, 39), (303, 28), (403, 82), (223, 317), (389, 107), (29, 20), (412, 156), (68, 558), (241, 86), (204, 94), (460, 176), (227, 135), (123, 86), (469, 78), (381, 658), (19, 147), (5, 428), (65, 209), (321, 79), (180, 134), (473, 180), (420, 917), (203, 111), (189, 176), (85, 15), (327, 198), (63, 210), (297, 119), (283, 36), (412, 320), (435, 225), (112, 50), (165, 8), (190, 597), (47, 52), (31, 595), (316, 182), (257, 562), (130, 288), (3, 50), (88, 40), (259, 92), (245, 107), (407, 105), (231, 136), (487, 226), (420, 41), (23, 156), (259, 4), (83, 497), (122, 389), (454, 376), (221, 3), (168, 145), (477, 185), (170, 835), (64, 450), (304, 337), (177, 165), (306, 259), (126, 128), (442, 195), (283, 410), (317, 641), (174, 250), (234, 33), (287, 57), (490, 183), (77, 469), (153, 61), (102, 104), (328, 53), (457, 919), (7, 63), (120, 183), (489, 6), (430, 0), (92, 165), (422, 56), (332, 628), (267, 227), (73, 592), (57, 315), (6, 140), (209, 16), (262, 26), (195, 69), (188, 21), (91, 20), (241, 391), (3, 842), (47, 705), (319, 44), (162, 249), (349, 287), (104, 24), (340, 456), (55, 919), (411, 1050), (189, 385), (318, 127), (138, 961), (214, 60), (34, 686), (327, 503), (184, 127), (57, 247), (453, 87), (133, 74), (320, 591), (82, 866), (278, 105), (398, 38), (22, 722), (359, 59), (227, 48), (192, 1373), (469, 211), (215, 563), (109, 204), (146, 86), (425, 21), (429, 147), (65, 46), (28, 86), (450, 736), (420, 792), (369, 1008), (482, 49), (249, 298), (468, 12), (392, 69), (184, 443), (94, 66), (320, 11), (306, 114), (353, 102), (377, 63), (317, 515), (93, 139), (3, 191), (222, 817), (192, 228), (231, 61), (291, 248), (5, 1098), (97, 57), (443, 21), (429, 26), (69,  ...

# %%
track_count_ = {}
for track in rechit_track_map_.keys():
    count_ = len(rechit_track_map_[track])
    if count_ in track_count_:
        track_count_[count_] += 1
    else:
        track_count_[count_] = 1

# %%
track_count_
# Out:
# {1: 2514,
#  2: 7028,
#  3: 3424,
#  4: 1663,
#  5: 512,
#  6: 210,
#  7: 125,
#  8: 84,
#  9: 55,
#  10: 43,
#  11: 24,
#  12: 18,
#  13: 12,
#  14: 9,
#  15: 11,
#  16: 8,
#  17: 2,
#  18: 2,
#  19: 2,
#  20: 2,
#  21: 2,
#  22: 2}

# %%
plt.clf()
ax_ = plt.subplot()
# Plot the 2D Histogram for Mono Rechits
ax_.set_title('Hits vs. Tracks')
#ax_.hist2d(track_count_.values(), track_count_.keys(), bins=20)
ax_.hist(track_count_.values(), weights=track_count_.keys(), bins=20)
plt.ylabel('Number of Tracks')
plt.yscale('log')
plt.xlabel('Number of Hits')
plt.savefig('plots/' + gen_event_ + '/track/hitdistribution')
plt.show()

# %%
plt.clf()
ax_ = plt.subplot()
# Plot the ,2D Histogram for Mono Rechits
ax_.set_title('MonoRechit Distribution of ' + param)
ax_.hist(track_count_.keys(), weights=track_count_.values(), bins=20, histtype='stepfilled', align='mid', orientation='vertical', density=True)
plt.xlabel('Value of ' + param)
plt.ylabel('Distribution of ' + param)
plt.title(param + ' Distribution')
plt.savefig('plots/' + gen_event_ + '/mono/' + param)
plt.show()
